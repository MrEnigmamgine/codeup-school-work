# %% [markdown]
# # Data Wrangling: Acquisition & Preparation
#
# In this lesson, we'll be acquiring and preparing some data from our SQL database.
#
# ## Learning Goals:

# %% [markdown]
#
# - Acquire a sample of data from SQL.
# - Identify null values, which nulls are 'deal-breakers', i.e. rows removed, which nulls should be represented by 0, and which should be replaced by a value from other methods, such as mean.
# - Identify outliers and decide what to do with them, if anything (remove, keep as-is, replace).
# - Data Structure: Aggregate as needed so that every row is an observation and each column is a variable (1 variable and not a measure).

# %%
# regular imports

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import env

# default pandas decimal number display format
pd.options.display.float_format = '{:20,.2f}'.format

import warnings
warnings.filterwarnings("ignore")

# Wrangling
from sklearn.model_selection import train_test_split

# %%
# from our acquire.py:
def get_connection(db, user=env.user, host=env.host, password=env.password):
    return f'mysql+pymysql://{user}:{password}@{host}/{db}'
    
sql_query = '''
SELECT * FROM properties_2017
JOIN predictions_2017 USING (parcelid)
WHERE transactiondate < '2018'
AND propertylandusetypeid = 261;
'''
    
def get_zillow_data():
    df = pd.read_sql(sql_query, get_connection('zillow'))
    df = df.drop(columns='id')
    return df

# %% [markdown]
# Acquire our dataframe:

# %%
df = get_zillow_data()

# %% [markdown]
# ### Acquire & Summarize
#
# Let's create a function that gives us a quick summary of our data. What might we want to see?
# - `.head()`
# - `.info()`
# - `.describe()`
# - `.value_counts()`
# - null counts (by column and by row)

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  14297519                    NaN                       NaN           NaN
# 1  17052889                    NaN                       NaN           NaN
# 2  14186244                    NaN                       NaN           NaN
# 3  12177905                    NaN                       NaN           NaN
# 4  12095076                   1.00                       NaN           NaN
#
#            bathroomcnt           bedroomcnt buildingclasstypeid  \
# 0                 3.50                 4.00                None
# 1                 1.00                 2.00                None
# 2                 2.00                 3.00                None
# 3                 3.00                 4.00                None
# 4                 3.00                 4.00                None
#
#    buildingqualitytypeid    calculatedbathnbr  decktypeid  ...  \
# 0                    NaN                 3.50         NaN  ...
# 1                    NaN                 1.00         NaN  ...
# 2                    NaN                 2.00         NaN  ...
# 3                   8.00                 3.00         NaN  ...
# 4                   9.00                 3.00         NaN  ...
#
#    structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# 0                  485,713.00         1,023,282.00             2,016.00
# 1                   88,000.00           464,000.00             2,016.00
# 2                   85,289.00           564,778.00             2,016.00
# 3                  108,918.00           145,143.00             2,016.00
# 4                  276,684.00           773,303.00             2,016.00
#
#   landtaxvaluedollarcnt            taxamount  taxdelinquencyflag  \
# 0            537,569.00            11,013.72                None
# 1            376,000.00             5,672.48                None
# 2            479,489.00             6,488.30                None
# 3             36,225.00             1,777.51                None
# 4            496,619.00             9,516.26                None
#
#    taxdelinquencyyear   censustractandblock             logerror  \
# 0                 NaN 60,590,630,072,012.00                 0.03
# 1                 NaN 61,110,010,023,006.00                 0.06
# 2                 NaN 60,590,218,022,012.00                 0.01
# 3                 NaN 60,373,001,001,006.00                -0.10
# 4                 NaN 60,374,608,001,014.00                -0.00
#
#    transactiondate
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01
#
# [5 rows x 60 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52441 entries, 0 to 52440
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      52441 non-null  int64
#  1   airconditioningtypeid         13638 non-null  float64
#  2   architecturalstyletypeid      70 non-null     float64
#  3   basementsqft                  47 non-null     float64
#  4   bathroomcnt                   52441 non-null  float64
#  5   bedroomcnt                    52441 non-null  float64
#  6   buildingclasstypeid           0 non-null      object
#  7   buildingqualitytypeid         33740 non-null  float64
#  8   calculatedbathnbr             52304 non-null  float64
#  9   decktypeid                    389 non-null    float64
#  10  finishedfloor1squarefeet      4381 non-null   float64
#  11  calculatedfinishedsquarefeet  52359 non-null  float64
#  12  finishedsquarefeet12          52194 non-null  float64
#  13  finishedsquarefeet13          0 non-null      object
#  14  finishedsquarefeet15          0 non-null      object
#  15  finishedsquarefeet50          4381 non-null   float64
#  16  finishedsquarefeet6           165 non-null    float64
#  17  fips                          52441 non-null  float64
#  18  fireplacecnt                  7243 non-null   float64
#  19  fullbathcnt                   52304 non-null  float64
#  20  garagecarcnt                  18015 non-null  float64
#  21  garagetotalsqft               18015 non-null  float64
#  22  hashottuborspa                1515 non-null   float64
#  23  heatingorsystemtypeid         33935 non-null  float64
#  24  latitude                      52441 non-null  float64
#  25  longitude                     52441 non-null  float64
#  26  lotsizesquarefeet             52072 non-null  float64
#  27  poolcnt                       11096 non-null  float64
#  28  poolsizesum                   867 non-null    float64
#  29  pooltypeid10                  444 non-null    float64
#  30  pooltypeid2                   1071 non-null   float64
#  31  pooltypeid7                   10009 non-null  float64
#  32  propertycountylandusecode     52441 non-null  object
#  33  propertylandusetypeid         52441 non-null  float64
#  34  propertyzoningdesc            33848 non-null  object
#  35  rawcensustractandblock        52441 non-null  float64
#  36  regionidcity                  51404 non-null  float64
#  37  regionidcounty                52441 non-null  float64
#  38  regionidneighborhood          19033 non-null  float64
#  39  regionidzip                   52415 non-null  float64
#  40  roomcnt                       52441 non-null  float64
#  41  storytypeid                   47 non-null     float64
#  42  threequarterbathnbr           6724 non-null   float64
#  43  typeconstructiontypeid        76 non-null     float64
#  44  unitcnt                       33847 non-null  float64
#  45  yardbuildingsqft17            1937 non-null   float64
#  46  yardbuildingsqft26            63 non-null     float64
#  47  yearbuilt                     52325 non-null  float64
#  48  numberofstories               14561 non-null  float64
#  49  fireplaceflag                 81 non-null     float64
#  50  structuretaxvaluedollarcnt    52357 non-null  float64
#  51  taxvaluedollarcnt             52440 non-null  float64
#  52  assessmentyear                52441 non-null  float64
#  53  landtaxvaluedollarcnt         52440 non-null  float64
#  54  taxamount                     52437 non-null  float64
#  55  taxdelinquencyflag            2079 non-null   object
#  56  taxdelinquencyyear            2079 non-null   float64
#  57  censustractandblock           52318 non-null  float64
#  58  logerror                      52441 non-null  float64
#  59  transactiondate               52441 non-null  object
# dtypes: float64(52), int64(1), object(7)
# memory usage: 24.0+ MB

# %%
df.describe().T
# Out:
#                                             count                  mean  \
# parcelid                                52,441.00         12,999,115.87
# airconditioningtypeid                   13,638.00                  2.44
# architecturalstyletypeid                    70.00                  7.10
# basementsqft                                47.00                678.98
# bathroomcnt                             52,441.00                  2.30
# bedroomcnt                              52,441.00                  3.30
# buildingqualitytypeid                   33,740.00                  6.26
# calculatedbathnbr                       52,304.00                  2.30
# decktypeid                                 389.00                 66.00
# finishedfloor1squarefeet                 4,381.00              1,545.61
# calculatedfinishedsquarefeet            52,359.00              1,922.89
# finishedsquarefeet12                    52,194.00              1,925.05
# finishedsquarefeet50                     4,381.00              1,566.37
# finishedsquarefeet6                        165.00              1,241.08
# fips                                    52,441.00              6,049.13
# fireplacecnt                             7,243.00                  1.21
# fullbathcnt                             52,304.00                  2.24
# garagecarcnt                            18,015.00                  1.95
# garagetotalsqft                         18,015.00                495.88
# hashottuborspa                           1,515.00                  1.00
# heatingorsystemtypeid                   33,935.00                  3.97
# latitude                                52,441.00         34,022,538.55
# longitude                               52,441.00       -118,194,190.28
# lotsizesquarefeet                       52,072.00             11,339.62
# poolcnt                                 11,096.00                  1.00
# poolsizesum                                867.00                518.32
# pooltypeid10                               444.00                  1.00
# pooltypeid2                              1,071.00                  1.00
# pooltypeid7                             10,009.00                  1.00
# propertylandusetypeid                   52,441.00                261.00
# rawcensustractandblock                  52,441.00         60,494,431.97
# regionidcity                            51,404.00             33,501.44
# regionidcounty                          52,441.00              2,524.59
# regionidneighborhood                    19,033.00            180,267.13
# regionidzip                             52,415.00             96,635.85
# roomcnt                                 52,441.00                  1.89
# storytypeid                                 47.00                  7.00
# threequarterbathnbr                      6,724.00                  1.01
# typeconstructiontypeid                      76.00                  5.97
# unitcnt                                 33,847.00                  1.00
# yardbuildingsqft17                       1,937.00                337.63
# yardbuildingsqft26                          63.00                225.62
# yearbuilt                               52,325.00              1,963.39
# numberofstories                         14,561.00                  1.41
# fireplaceflag                               81.00                  1.00
# structuretaxvaluedollarcnt              52,357.00            196,533.75
# taxvaluedollarcnt                       52,440.00            529,688.16
# assessmentyear                          52,441.00              2,016.00
# landtaxvaluedollarcnt                   52,440.00            333,465.48
# taxamount                               52,437.00              6,453.51
# taxdelinquencyyear                       2,079.00                 14.10
# censustractandblock                     52,318.00 60,502,401,189,819.98
# logerror                                52,441.00                  0.02
#
#                                               std                   min  \
# parcelid                             3,411,444.02         10,711,855.00
# airconditioningtypeid                        3.85                  1.00
# architecturalstyletypeid                     2.67                  2.00
# basementsqft                               711.83                 38.00
# bathroomcnt                                  1.02                  0.00
# bedroomcnt                                   0.95                  0.00
# buildingqualitytypeid                        1.72                  1.00
# calculatedbathnbr                            1.02                  1.00
# decktypeid                                   0.00                 66.00
# finishedfloor1squarefeet                   674.87                184.00
# calculatedfinishedsquarefeet             1,004.37                128.00
# finishedsquarefeet12                     1,004.28                128.00
# finishedsquarefeet50                       744.52                184.00
# finishedsquarefeet6                        776.96                380.00
# fips                                        21.03              6,037.00
# fireplacecnt                                 0.51                  1.00
# fullbathcnt                                  0.99                  1.00
# garagecarcnt                                 0.55                  0.00
# garagetotalsqft                            157.04                  0.00
# hashottuborspa                               0.00                  1.00
# heatingorsystemtypeid                        2.56                  1.00
# latitude                               273,978.70         33,340,620.00
# longitude                              356,662.63       -119,475,416.00
# lotsizesquarefeet                       86,747.63                236.00
# poolcnt                                      0.00                  1.00
# poolsizesum                                156.47                 24.00
# pooltypeid10                                 0.00                  1.00
# pooltypeid2                                  0.00                  1.00
# pooltypeid7                                  0.00                  1.00
# propertylandusetypeid                        0.00                261.00
# rawcensustractandblock                 208,689.18         60,371,011.10
# regionidcity                            49,175.19              3,491.00
# regionidcounty                             803.99              1,286.00
# regionidneighborhood                   159,824.93              6,952.00
# regionidzip                              4,605.11             95,982.00
# roomcnt                                      3.15                  0.00
# storytypeid                                  0.00                  7.00
# threequarterbathnbr                          0.14                  1.00
# typeconstructiontypeid                       0.23                  4.00
# unitcnt                                      0.03                  1.00
# yardbuildingsqft17                         250.02                 11.00
# yardbuildingsqft26                         188.51                 12.00
# yearbuilt                                   23.13              1,878.00
# numberofstories                              0.54                  1.00
# fireplaceflag                                0.00                  1.00
# structuretaxvaluedollarcnt             254,340.14                129.00
# taxvaluedollarcnt                      751,894.55              1,000.00
# assessmentyear                               0.00              2,016.00
# landtaxvaluedollarcnt                  570,527.80                161.00
# taxamount                                8,755.57                 49.18
# taxdelinquencyyear                           2.39                  4.00
# censustractandblock          1,859,036,273,451.59 60,371,011,101,000.00
# logerror                                     0.18                 -4.66
#
#                                                25%                   50%  \
# parcelid                             11,510,217.00         12,577,645.00
# airconditioningtypeid                         1.00                  1.00
# architecturalstyletypeid                      7.00                  7.00
# basementsqft                                263.50                512.00
# bathroomcnt                                   2.00                  2.00
# bedroomcnt                                    3.00                  3.00
# buildingqualitytypeid                         5.00                  6.00
# calculatedbathnbr                             2.00                  2.00
# decktypeid                                   66.00                 66.00
# finishedfloor1squarefeet                  1,151.00              1,410.00
# calculatedfinishedsquarefeet              1,268.00              1,659.00
# finishedsquarefeet12                      1,270.00              1,660.50
# finishedsquarefeet50                      1,152.00              1,414.00
# finishedsquarefeet6                         784.00              1,008.00
# fips                                      6,037.00              6,037.00
# fireplacecnt                                  1.00                  1.00
# fullbathcnt                                   2.00                  2.00
# garagecarcnt                                  2.00                  2.00
# garagetotalsqft                             426.00                462.00
# hashottuborspa                                1.00                  1.00
# heatingorsystemtypeid                         2.00                  2.00
# latitude                             33,826,906.00         34,023,782.00
# longitude                          -118,400,690.00       -118,153,082.00
# lotsizesquarefeet                         5,583.00              6,840.50
# poolcnt                                       1.00                  1.00
# poolsizesum                                 424.50                500.00
# pooltypeid10                                  1.00                  1.00
# pooltypeid2                                   1.00                  1.00
# pooltypeid7                                   1.00                  1.00
# propertylandusetypeid                       261.00                261.00
# rawcensustractandblock               60,374,012.02         60,376,201.02
# regionidcity                             12,447.00             24,812.00
# regionidcounty                            1,286.00              3,101.00
# regionidneighborhood                     41,131.00            118,208.00
# regionidzip                              96,206.00             96,412.00
# roomcnt                                       0.00                  0.00
# storytypeid                                   7.00                  7.00
# threequarterbathnbr                           1.00                  1.00
# typeconstructiontypeid                        6.00                  6.00
# unitcnt                                       1.00                  1.00
# yardbuildingsqft17                          200.00                280.00
# yardbuildingsqft26                           71.50                180.00
# yearbuilt                                 1,950.00              1,961.00
# numberofstories                               1.00                  1.00
# fireplaceflag                                 1.00                  1.00
# structuretaxvaluedollarcnt               77,071.00            131,811.00
# taxvaluedollarcnt                       193,747.50            373,612.00
# assessmentyear                            2,016.00              2,016.00
# landtaxvaluedollarcnt                    76,020.75            218,032.00
# taxamount                                 2,656.22              4,647.74
# taxdelinquencyyear                           14.00                 15.00
# censustractandblock          60,374,012,032,004.25 60,376,203,011,013.50
# logerror                                     -0.02                  0.01
#
#                                                75%                    max
# parcelid                             14,129,530.00         167,687,839.00
# airconditioningtypeid                         1.00                  13.00
# architecturalstyletypeid                      7.00                  21.00
# basementsqft                                809.50               3,560.00
# bathroomcnt                                   3.00                  18.00
# bedroomcnt                                    4.00                  14.00
# buildingqualitytypeid                         8.00                  12.00
# calculatedbathnbr                             3.00                  18.00
# decktypeid                                   66.00                  66.00
# finishedfloor1squarefeet                  1,759.00               6,912.00
# calculatedfinishedsquarefeet              2,306.00              21,929.00
# finishedsquarefeet12                      2,308.00              21,929.00
# finishedsquarefeet50                      1,770.00              12,467.00
# finishedsquarefeet6                       1,320.00               5,598.00
# fips                                      6,059.00               6,111.00
# fireplacecnt                                  1.00                   5.00
# fullbathcnt                                   3.00                  18.00
# garagecarcnt                                  2.00                  14.00
# garagetotalsqft                             567.00               4,251.00
# hashottuborspa                                1.00                   1.00
# heatingorsystemtypeid                         7.00                  24.00
# latitude                             34,187,150.00          34,818,767.00
# longitude                          -117,929,164.00        -117,554,636.00
# lotsizesquarefeet                         8,798.25           6,971,010.00
# poolcnt                                       1.00                   1.00
# poolsizesum                                 600.00               1,500.00
# pooltypeid10                                  1.00                   1.00
# pooltypeid2                                   1.00                   1.00
# pooltypeid7                                   1.00                   1.00
# propertylandusetypeid                       261.00                 261.00
# rawcensustractandblock               60,590,423.26          61,110,091.00
# regionidcity                             40,227.00             396,556.00
# regionidcounty                            3,101.00               3,101.00
# regionidneighborhood                    274,514.00             764,167.00
# regionidzip                              96,995.00             399,675.00
# roomcnt                                       5.00                  15.00
# storytypeid                                   7.00                   7.00
# threequarterbathnbr                           1.00                   7.00
# typeconstructiontypeid                        6.00                   6.00
# unitcnt                                       1.00                   3.00
# yardbuildingsqft17                          400.00               3,191.00
# yardbuildingsqft26                          317.00                 868.00
# yearbuilt                                 1,979.00               2,016.00
# numberofstories                               2.00                   6.00
# fireplaceflag                                 1.00                   1.00
# structuretaxvaluedollarcnt              226,334.00           9,164,901.00
# taxvaluedollarcnt                       619,301.25          49,061,236.00
# assessmentyear                            2,016.00               2,016.00
# landtaxvaluedollarcnt                   408,606.75          48,952,198.00
# taxamount                                 7,377.50             586,639.30
# taxdelinquencyyear                           15.00                  99.00
# censustractandblock          60,590,423,261,751.25 483,030,105,084,015.00
# logerror                                      0.04                   5.26

# %%
print(f'r0ws: {df.shape[0]}')
print(f'co1umns: {df.shape[1]}')
# Out:
# r0ws: 52441
# co1umns: 60

# %%
for col in df.columns:
    print(col)
    print(df[col].value_counts())
# Out:
# parcelid
# 11991059    3
# 11957553    2
# 12478591    2
# 12035592    2
# 12443331    2
#            ..
# 11494547    1
# 10976762    1
# 12650619    1
# 12650850    1
# 12826780    1
# Name: parcelid, Length: 52320, dtype: int64
# airconditioningtypeid
#  1.00    11895
# 13.00     1568
#  5.00      159
# 11.00       16
# Name: airconditioningtypeid, dtype: int64
# architecturalstyletypeid
#  7.00    62
#  3.00     3
#  2.00     2
# 21.00     2
#  8.00     1
# Name: architecturalstyletypeid, dtype: int64
# basementsqft
#   900.00    2
#   640.00    2
#   100.00    2
#   515.00    2
#   273.00    2
#   912.00    2
#   314.00    1
#   819.00    1
# 1,809.00    1
#   604.00    1
#   126.00    1
#   588.00    1
#   786.00    1
#   669.00    1
#   800.00    1
#   396.00    1
#   112.00    1
#   645.00    1
#   384.00    1
# 1,969.00    1
#   252.00    1
#   600.00    1
# 1,218.00    1
#   280.00    1
#   300.00    1
#   224.00    1
#   512.00    1
#   380.00    1
#   204.00    1
#   200.00    1
#    90.00    1
# 3,112.00    1
#   405.00    1
# 1,252.00    1
#   254.00    1
# 3,560.00    1
#   352.00    1
#   168.00    1
#   394.00    1
# 1,416.00    1
#    38.00    1
# Name: basementsqft, dtype: int64
# bathroomcnt
#  2.00    21893
#  3.00    10673
#  1.00     9568
#  2.50     3934
#  4.00     2227
#  3.50      918
#  1.50      841
#  5.00      803
#  4.50      687
#  6.00      322
#  5.50      224
#  0.00      121
#  7.00       88
#  8.00       53
#  6.50       47
#  7.50       16
#  9.00       13
# 10.00        5
# 11.00        3
#  8.50        3
# 18.00        1
# 13.00        1
# Name: bathroomcnt, dtype: int64
# bedroomcnt
#  3.00    23359
#  4.00    15240
#  2.00     8340
#  5.00     3973
#  6.00      635
#  1.00      612
#  0.00      137
#  7.00      106
#  8.00       24
#  9.00        8
# 12.00        3
# 10.00        2
# 14.00        1
# 11.00        1
# Name: bedroomcnt, dtype: int64
# buildingclasstypeid
# Series([], Name: buildingclasstypeid, dtype: int64)
# buildingqualitytypeid
#  6.00    10289
#  8.00     8244
#  4.00     8156
#  7.00     3427
#  5.00     1513
#  9.00     1121
# 11.00      514
# 10.00      230
#  3.00      152
# 12.00       81
#  1.00        8
#  2.00        5
# Name: buildingqualitytypeid, dtype: int64
# calculatedbathnbr
#  2.00    21893
#  3.00    10673
#  1.00     9568
#  2.50     3926
#  4.00     2227
#  3.50      918
#  1.50      834
#  5.00      803
#  4.50      687
#  6.00      322
#  5.50      223
#  7.00       88
#  8.00       53
#  6.50       47
#  7.50       16
#  9.00       13
# 10.00        5
# 11.00        3
#  8.50        3
# 18.00        1
# 13.00        1
# Name: calculatedbathnbr, dtype: int64
# decktypeid
# 66.00    389
# Name: decktypeid, dtype: int64
# finishedfloor1squarefeet
# 1,252.00    22
# 1,205.00    21
# 1,462.00    21
# 1,227.00    19
# 1,431.00    17
#             ..
# 1,708.00     1
#   922.00     1
# 2,062.00     1
# 4,300.00     1
# 2,652.00     1
# Name: finishedfloor1squarefeet, Length: 1553, dtype: int64
# calculatedfinishedsquarefeet
# 1,120.00    128
# 1,200.00    119
# 1,080.00    102
# 1,040.00     86
#   936.00     86
#            ...
# 7,088.00      1
#   604.00      1
# 5,422.00      1
#   534.00      1
# 5,655.00      1
# Name: calculatedfinishedsquarefeet, Length: 4723, dtype: int64
# finishedsquarefeet12
# 1,120.00    127
# 1,200.00    118
# 1,080.00    102
#   936.00     86
# 1,040.00     85
#            ...
# 9,843.00      1
# 7,088.00      1
#   604.00      1
# 5,422.00      1
# 5,655.00      1
# Name: finishedsquarefeet12, Length: 4716, dtype: int64
# finishedsquarefeet13
# Series([], Name: finishedsquarefeet13, dtype: int64)
# finishedsquarefeet15
# Series([], Name: finishedsquarefeet15, dtype: int64)
# finishedsquarefeet50
# 1,252.00    22
# 1,462.00    21
# 1,205.00    21
# 1,227.00    19
# 1,431.00    17
#             ..
# 1,533.00     1
# 1,708.00     1
#   922.00     1
# 2,062.00     1
# 2,652.00     1
# Name: finishedsquarefeet50, Length: 1572, dtype: int64
# finishedsquarefeet6
#   952.00    4
#   520.00    3
#   750.00    2
#   765.00    2
#   845.00    2
#            ..
# 1,178.00    1
#   670.00    1
#   748.00    1
# 1,200.00    1
#   905.00    1
# Name: finishedsquarefeet6, Length: 155, dtype: int64
# fips
# 6,037.00    33910
# 6,059.00    14136
# 6,111.00     4395
# Name: fips, dtype: int64
# fireplacecnt
# 1.00    6031
# 2.00     945
# 3.00     229
# 4.00      35
# 5.00       3
# Name: fireplacecnt, dtype: int64
# fullbathcnt
#  2.00    25831
#  3.00    11600
#  1.00    10402
#  4.00     2915
#  5.00     1022
#  6.00      359
#  7.00       96
#  8.00       56
#  9.00       13
# 10.00        5
# 11.00        3
# 18.00        1
# 13.00        1
# Name: fullbathcnt, dtype: int64
# garagecarcnt
#  2.00    14802
#  1.00     2202
#  3.00      621
#  4.00      254
#  0.00       65
#  5.00       45
#  6.00       13
#  7.00        3
# 10.00        3
#  8.00        2
#  9.00        2
# 11.00        1
# 13.00        1
# 14.00        1
# Name: garagecarcnt, dtype: int64
# garagetotalsqft
#   400.00    788
#   441.00    678
#   462.00    660
#   360.00    648
#   460.00    571
#            ...
#   275.00      1
# 1,056.00      1
#   261.00      1
# 1,155.00      1
#   957.00      1
# Name: garagetotalsqft, Length: 839, dtype: int64
# hashottuborspa
# 1.00    1515
# Name: hashottuborspa, dtype: int64
# heatingorsystemtypeid
#  2.00    20736
#  7.00    12565
#  6.00      517
# 20.00       85
# 13.00       16
#  1.00        7
# 18.00        6
# 10.00        2
# 24.00        1
# Name: heatingorsystemtypeid, dtype: int64
# latitude
# 34,047,500.00    12
# 34,487,900.00     7
# 34,101,300.00     7
# 33,494,800.00     7
# 34,137,792.00     6
#                  ..
# 34,023,323.00     1
# 34,034,633.00     1
# 33,840,741.00     1
# 33,511,474.00     1
# 33,937,685.00     1
# Name: latitude, Length: 50478, dtype: int64
# longitude
# -118,249,000.00    12
# -117,835,000.00     8
# -117,670,000.00     7
# -118,172,000.00     7
# -117,830,000.00     7
#                    ..
# -118,107,541.00     1
# -118,410,753.00     1
# -118,116,393.00     1
# -118,170,213.00     1
# -117,996,709.00     1
# Name: longitude, Length: 50764, dtype: int64
# lotsizesquarefeet
#   6,000.00    876
#   5,000.00    414
#   7,200.00    307
#   7,000.00    287
#   6,500.00    272
#              ...
#  11,061.00      1
#  15,757.00      1
# 100,066.00      1
#   3,701.00      1
#  47,405.00      1
# Name: lotsizesquarefeet, Length: 14292, dtype: int64
# poolcnt
# 1.00    11096
# Name: poolcnt, dtype: int64
# poolsizesum
#   450.00    89
#   400.00    38
#   500.00    30
#   600.00    27
#   512.00    25
#             ..
#   275.00     1
#   434.00     1
# 1,070.00     1
#   368.00     1
#   780.00     1
# Name: poolsizesum, Length: 262, dtype: int64
# pooltypeid10
# 1.00    444
# Name: pooltypeid10, dtype: int64
# pooltypeid2
# 1.00    1071
# Name: pooltypeid2, dtype: int64
# pooltypeid7
# 1.00    10009
# Name: pooltypeid7, dtype: int64
# propertycountylandusecode
# 0100    26782
# 122     13067
# 0101     6413
# 1111     3362
# 1        1069
# 1110     1025
# 0104      369
# 010G       94
# 0103       91
# 0108       57
# 010M       53
# 0109       18
# 1112        8
# 0110        6
# 0113        6
# 0141        4
# 0102        3
# 0105        3
# 010V        2
# 0111        2
# 0130        2
# 0131        1
# 0133        1
# 0115        1
# 010L        1
# 0114        1
# Name: propertycountylandusecode, dtype: int64
# propertylandusetypeid
# 261.00    52441
# Name: propertylandusetypeid, dtype: int64
# propertyzoningdesc
# LAR1          6498
# LARS          1385
# LBR1N         1111
# SCUR2          712
# LARE11         612
#               ...
# LCR3800015       1
# PSR6*            1
# LARE             1
# MYR3PY           1
# BFA15000*        1
# Name: propertyzoningdesc, Length: 1286, dtype: int64
# rawcensustractandblock
# 60,379,203.39    36
# 60,379,201.16    32
# 60,371,417.00    24
# 60,590,320.57    24
# 60,590,320.42    23
#                  ..
# 60,375,775.01     1
# 60,375,775.04     1
# 60,375,353.00     1
# 60,372,407.01     1
# 60,375,034.02     1
# Name: rawcensustractandblock, Length: 31441, dtype: int64
# regionidcity
# 12,447.00    11452
#  5,534.00     1795
# 40,227.00     1492
# 46,298.00     1428
# 16,764.00     1087
#              ...
# 32,927.00        3
# 31,134.00        2
# 36,078.00        1
# 10,815.00        1
# 21,395.00        1
# Name: regionidcity, Length: 175, dtype: int64
# regionidcounty
# 3,101.00    33910
# 1,286.00    14136
# 2,061.00     4395
# Name: regionidcounty, dtype: int64
# regionidneighborhood
#  48,570.00    503
# 118,208.00    476
#  27,080.00    448
# 274,049.00    391
#  51,906.00    374
#              ...
# 763,079.00      1
# 764,138.00      1
# 763,090.00      1
# 764,167.00      1
# 762,940.00      1
# Name: regionidneighborhood, Length: 437, dtype: int64
# regionidzip
# 97,319.00    776
# 97,318.00    674
# 97,329.00    564
# 97,328.00    519
# 97,118.00    498
#             ...
# 96,467.00      1
# 97,092.00      1
# 96,148.00      1
# 96,038.00      1
# 97,088.00      1
# Name: regionidzip, Length: 381, dtype: int64
# roomcnt
#  0.00    37853
#  6.00     3982
#  7.00     3615
#  8.00     2813
#  5.00     1890
#  9.00     1176
#  4.00      521
# 10.00      339
# 11.00      108
#  3.00       79
# 12.00       35
#  2.00       12
# 13.00       10
# 14.00        6
#  1.00        1
# 15.00        1
# Name: roomcnt, dtype: int64
# storytypeid
# 7.00    47
# Name: storytypeid, dtype: int64
# threequarterbathnbr
# 1.00    6645
# 2.00      70
# 3.00       8
# 7.00       1
# Name: threequarterbathnbr, dtype: int64
# typeconstructiontypeid
# 6.00    75
# 4.00     1
# Name: typeconstructiontypeid, dtype: int64
# unitcnt
# 1.00    33817
# 2.00       29
# 3.00        1
# Name: unitcnt, dtype: int64
# yardbuildingsqft17
#   200.00    85
#   240.00    71
#   300.00    49
#   400.00    37
#   288.00    34
#             ..
#   319.00     1
# 1,113.00     1
#   415.00     1
#   913.00     1
#   201.00     1
# Name: yardbuildingsqft17, Length: 504, dtype: int64
# yardbuildingsqft26
# 120.00    3
#  56.00    2
# 300.00    2
# 240.00    2
# 448.00    2
# 196.00    1
# 140.00    1
#  48.00    1
# 284.00    1
#  39.00    1
# 133.00    1
# 486.00    1
# 250.00    1
#  91.00    1
# 491.00    1
#  16.00    1
# 204.00    1
#  71.00    1
#  28.00    1
# 195.00    1
# 292.00    1
# 231.00    1
#  30.00    1
# 320.00    1
# 384.00    1
# 180.00    1
#  49.00    1
# 868.00    1
# 462.00    1
# 461.00    1
# 368.00    1
# 105.00    1
#  37.00    1
#  88.00    1
# 160.00    1
#  45.00    1
# 752.00    1
# 169.00    1
#  21.00    1
# 200.00    1
# 113.00    1
#  41.00    1
# 314.00    1
#  12.00    1
# 414.00    1
#  66.00    1
# 648.00    1
# 174.00    1
# 218.00    1
#  60.00    1
# 336.00    1
# 108.00    1
# 144.00    1
# 216.00    1
# 360.00    1
#  72.00    1
# 576.00    1
# Name: yardbuildingsqft26, dtype: int64
# yearbuilt
# 1,955.00    1899
# 1,950.00    1608
# 1,954.00    1520
# 1,953.00    1485
# 1,956.00    1387
#             ...
# 1,892.00       1
# 1,878.00       1
# 1,882.00       1
# 1,894.00       1
# 1,880.00       1
# Name: yearbuilt, Length: 133, dtype: int64
# numberofstories
# 1.00    8890
# 2.00    5318
# 3.00     352
# 6.00       1
# Name: numberofstories, dtype: int64
# fireplaceflag
# 1.00    81
# Name: fireplaceflag, dtype: int64
# structuretaxvaluedollarcnt
# 100,000.00    50
# 200,000.00    36
#  90,000.00    32
#  32,489.00    28
#  95,000.00    27
#               ..
# 384,779.00     1
#  99,143.00     1
#  69,732.00     1
#  81,625.00     1
#  32,797.00     1
# Name: structuretaxvaluedollarcnt, Length: 37333, dtype: int64
# taxvaluedollarcnt
# 455,000.00    34
# 600,000.00    30
# 500,000.00    24
# 450,000.00    24
# 550,000.00    24
#               ..
# 209,341.00     1
# 203,304.00     1
# 497,409.00     1
# 421,945.00     1
#  49,546.00     1
# Name: taxvaluedollarcnt, Length: 38942, dtype: int64
# assessmentyear
# 2,016.00    52441
# Name: assessmentyear, dtype: int64
# landtaxvaluedollarcnt
#  21,299.00    95
#  30,210.00    63
#  22,755.00    63
#  16,522.00    54
#  16,749.00    51
#               ..
# 189,725.00     1
# 304,486.00     1
# 325,476.00     1
# 280,040.00     1
# 283,704.00     1
# Name: landtaxvaluedollarcnt, Length: 36912, dtype: int64
# taxamount
#   345.72    4
# 5,871.38    3
# 2,172.75    3
# 3,347.58    3
#   855.16    3
#            ..
# 3,114.95    1
# 4,050.56    1
# 4,996.36    1
#   683.35    1
# 6,317.15    1
# Name: taxamount, Length: 50834, dtype: int64
# taxdelinquencyflag
# Y    2079
# Name: taxdelinquencyflag, dtype: int64
# taxdelinquencyyear
# 15.00    1131
# 14.00     560
# 13.00     129
# 12.00      81
# 11.00      79
# 10.00      47
#  9.00      33
#  8.00       8
#  7.00       8
#  6.00       1
# 99.00       1
#  4.00       1
# Name: taxdelinquencyyear, dtype: int64
# censustractandblock
# 60,379,201,162,006.00    32
# 60,379,203,391,054.00    27
# 60,590,320,571,003.00    24
# 60,371,417,002,000.00    24
# 60,590,320,421,002.00    23
#                          ..
# 60,372,714,001,001.00     1
# 60,371,954,004,007.00     1
# 60,379,108,051,066.00     1
# 60,590,758,081,024.00     1
# 60,375,034,021,020.00     1
# Name: censustractandblock, Length: 31404, dtype: int64
# logerror
#  0.00    5
#  0.00    5
#  0.00    5
#  0.00    5
#  0.02    4
#         ..
#  0.02    1
#  0.02    1
# -0.03    1
#  0.03    1
#  0.04    1
# Name: logerror, Length: 52180, dtype: int64
# transactiondate
# 2017-06-30    810
# 2017-04-28    617
# 2017-05-31    566
# 2017-07-28    546
# 2017-08-31    528
#              ...
# 2017-05-07      1
# 2017-05-13      1
# 2017-05-20      1
# 2017-06-11      1
# 2017-09-25      1
# Name: transactiondate, Length: 257, dtype: int64

# %% [markdown]
# ## Nulls By Column
#
# Sure, using built in methods is easy enough. But what about getting our nulls by column and nulls by row?
#
# Let's look at nulls by column. Let's start by using `.isnull()`:

# %%
df.isnull().head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0     False                   True                      True          True
# 1     False                   True                      True          True
# 2     False                   True                      True          True
# 3     False                   True                      True          True
# 4     False                  False                      True          True
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0        False       False                 True                   True
# 1        False       False                 True                   True
# 2        False       False                 True                   True
# 3        False       False                 True                  False
# 4        False       False                 True                  False
#
#    calculatedbathnbr  decktypeid  ...  structuretaxvaluedollarcnt  \
# 0              False        True  ...                       False
# 1              False        True  ...                       False
# 2              False        True  ...                       False
# 3              False        True  ...                       False
# 4              False        True  ...                       False
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0              False           False                  False      False
# 1              False           False                  False      False
# 2              False           False                  False      False
# 3              False           False                  False      False
# 4              False           False                  False      False
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                True                True                False     False
# 1                True                True                False     False
# 2                True                True                False     False
# 3                True                True                False     False
# 4                True                True                False     False
#
#    transactiondate
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
#
# [5 rows x 60 columns]

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  14297519                    NaN                       NaN           NaN
# 1  17052889                    NaN                       NaN           NaN
# 2  14186244                    NaN                       NaN           NaN
# 3  12177905                    NaN                       NaN           NaN
# 4  12095076                   1.00                       NaN           NaN
#
#            bathroomcnt           bedroomcnt buildingclasstypeid  \
# 0                 3.50                 4.00                None
# 1                 1.00                 2.00                None
# 2                 2.00                 3.00                None
# 3                 3.00                 4.00                None
# 4                 3.00                 4.00                None
#
#    buildingqualitytypeid    calculatedbathnbr  decktypeid  ...  \
# 0                    NaN                 3.50         NaN  ...
# 1                    NaN                 1.00         NaN  ...
# 2                    NaN                 2.00         NaN  ...
# 3                   8.00                 3.00         NaN  ...
# 4                   9.00                 3.00         NaN  ...
#
#    structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# 0                  485,713.00         1,023,282.00             2,016.00
# 1                   88,000.00           464,000.00             2,016.00
# 2                   85,289.00           564,778.00             2,016.00
# 3                  108,918.00           145,143.00             2,016.00
# 4                  276,684.00           773,303.00             2,016.00
#
#   landtaxvaluedollarcnt            taxamount  taxdelinquencyflag  \
# 0            537,569.00            11,013.72                None
# 1            376,000.00             5,672.48                None
# 2            479,489.00             6,488.30                None
# 3             36,225.00             1,777.51                None
# 4            496,619.00             9,516.26                None
#
#    taxdelinquencyyear   censustractandblock             logerror  \
# 0                 NaN 60,590,630,072,012.00                 0.03
# 1                 NaN 61,110,010,023,006.00                 0.06
# 2                 NaN 60,590,218,022,012.00                 0.01
# 3                 NaN 60,373,001,001,006.00                -0.10
# 4                 NaN 60,374,608,001,014.00                -0.00
#
#    transactiondate
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
# 3       2017-01-01
# 4       2017-01-01
#
# [5 rows x 60 columns]

# %% [markdown]
# This boolean DataFrame can be aggregated:

# %%
df.isnull().sum()[:10]
# Out:
# parcelid                        0
# airconditioningtypeid       38803
# architecturalstyletypeid    52371
# basementsqft                52394
# bathroomcnt                     0
# bedroomcnt                      0
# buildingclasstypeid         52441
# buildingqualitytypeid       18701
# calculatedbathnbr             137
# decktypeid                  52052
# dtype: int64

# %%
df.shape[0] # Number of rows
# Out:
# 52441

# %%
(df.isnull().sum()/df.shape[0]*100)[:10] # Percentage of nulls in each column
# Out:
# parcelid                                   0.00
# airconditioningtypeid                     73.99
# architecturalstyletypeid                  99.87
# basementsqft                              99.91
# bathroomcnt                                0.00
# bedroomcnt                                 0.00
# buildingclasstypeid                      100.00
# buildingqualitytypeid                     35.66
# calculatedbathnbr                          0.26
# decktypeid                                99.26
# dtype: float64

# %%
df.isnull().mean()[:10]
# Out:
# parcelid                                   0.00
# airconditioningtypeid                      0.74
# architecturalstyletypeid                   1.00
# basementsqft                               1.00
# bathroomcnt                                0.00
# bedroomcnt                                 0.00
# buildingclasstypeid                        1.00
# buildingqualitytypeid                      0.36
# calculatedbathnbr                          0.00
# decktypeid                                 0.99
# dtype: float64

# %%
nulls_col = pd.DataFrame({'num_rows_missing': df.isnull().sum(), 
              'percent_rows_missing': (df.isnull().sum() / df.shape[0] * 100)})

nulls_col.sort_values(by='num_rows_missing', ascending=False).head(10)
# Out:
#                           num_rows_missing  percent_rows_missing
# finishedsquarefeet15                 52441                100.00
# buildingclasstypeid                  52441                100.00
# finishedsquarefeet13                 52441                100.00
# storytypeid                          52394                 99.91
# basementsqft                         52394                 99.91
# yardbuildingsqft26                   52378                 99.88
# architecturalstyletypeid             52371                 99.87
# typeconstructiontypeid               52365                 99.86
# fireplaceflag                        52360                 99.85
# finishedsquarefeet6                  52276                 99.69

# %% [markdown]
# Lets put this together in a function:

# %%
def nulls_by_col(df):
    num_missing = df.isnull().sum()
    rows = df.shape[0]
    prcnt_miss = num_missing / rows * 100
    cols_missing = pd.DataFrame({'num_rows_missing': num_missing, 'percent_rows_missing': prcnt_miss})
    return cols_missing.sort_values(by='num_rows_missing', ascending=False)

# %% [markdown]
# ## Nulls by Row
#
# Okay, now how might we look at the number/percent of nulls in each row?

# %%
df.isnull().sum(axis=1)
# Out:
# 0        30
# 1        27
# 2        28
# 3        27
# 4        25
#          ..
# 52436    29
# 52437    28
# 52438    26
# 52439    28
# 52440    29
# Length: 52441, dtype: int64

# %% [markdown]
# Looks like the first row has 30 nulls. Lets look at it:

# %%
df.head(1)[df.head(1).isna()]
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0       NaN                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt buildingclasstypeid  buildingqualitytypeid  \
# 0          NaN         NaN                None                    NaN
#
#    calculatedbathnbr  decktypeid  ...  structuretaxvaluedollarcnt  \
# 0                NaN         NaN  ...                         NaN
#
#    taxvaluedollarcnt  assessmentyear landtaxvaluedollarcnt taxamount  \
# 0                NaN             NaN                   NaN       NaN
#
#    taxdelinquencyflag  taxdelinquencyyear  censustractandblock  logerror  \
# 0                None                 NaN                  NaN       NaN
#
#    transactiondate
# 0              NaN
#
# [1 rows x 60 columns]

# %% [markdown]
# Notice that both `NaN` and `None` are considered as null. Anyways, lets look at our null counts by row again:

# %%
df.isnull().sum(axis=1)
# Out:
# 0        30
# 1        27
# 2        28
# 3        27
# 4        25
#          ..
# 52436    29
# 52437    28
# 52438    26
# 52439    28
# 52440    29
# Length: 52441, dtype: int64

# %% [markdown]
# Lets turn it into a percentage:

# %%
df.isnull().sum(axis=1) / df.shape[1] * 100
# Out:
# 0                      50.00
# 1                      45.00
# 2                      46.67
# 3                      45.00
# 4                      41.67
#                 ...
# 52436                  48.33
# 52437                  46.67
# 52438                  43.33
# 52439                  46.67
# 52440                  48.33
# Length: 52441, dtype: float64

# %%
nulls_row = pd.DataFrame({'num_cols_missing': df.isnull().sum(axis=1),
              'percent_cols_missing': df.isnull().sum(axis=1)/df.shape[1]*100})

nulls_row
# Out:
#        num_cols_missing  percent_cols_missing
# 0                    30                 50.00
# 1                    27                 45.00
# 2                    28                 46.67
# 3                    27                 45.00
# 4                    25                 41.67
# ...                 ...                   ...
# 52436                29                 48.33
# 52437                28                 46.67
# 52438                26                 43.33
# 52439                28                 46.67
# 52440                29                 48.33
#
# [52441 rows x 2 columns]

# %% [markdown]
# Can we get our `parcelid` back onto this new DataFrame?

# %%
nulls_row = df.merge(nulls_row,
                        left_index=True,
                        right_index=True)[['parcelid', 'num_cols_missing', 'percent_cols_missing']]

nulls_row
# Out:
#        parcelid  num_cols_missing  percent_cols_missing
# 0      14297519                30                 50.00
# 1      17052889                27                 45.00
# 2      14186244                28                 46.67
# 3      12177905                27                 45.00
# 4      12095076                25                 41.67
# ...         ...               ...                   ...
# 52436  12412492                29                 48.33
# 52437  11000655                28                 46.67
# 52438  17239384                26                 43.33
# 52439  12773139                28                 46.67
# 52440  12826780                29                 48.33
#
# [52441 rows x 3 columns]

# %%
nulls_row.sort_values(by='num_cols_missing', ascending=False)
# Out:
#         parcelid  num_cols_missing  percent_cols_missing
# 28116  167687839                42                 70.00
# 9001   167686999                42                 70.00
# 41468   17188862                41                 68.33
# 13429   14460039                40                 66.67
# 48597   14341510                39                 65.00
# ...          ...               ...                   ...
# 42219   17292665                20                 33.33
# 21757   17194590                20                 33.33
# 20841   17270021                20                 33.33
# 10432   17097816                19                 31.67
# 12733   17215105                19                 31.67
#
# [52441 rows x 3 columns]

# %%
def nulls_by_row(df):
    num_missing = df.isnull().sum(axis=1)
    prcnt_miss = num_missing / df.shape[1] * 100
    rows_missing = pd.DataFrame({'num_cols_missing': num_missing, 'percent_cols_missing': prcnt_miss})
    rows_missing = df.merge(rows_missing,
                        left_index=True,
                        right_index=True)[['parcelid', 'num_cols_missing', 'percent_cols_missing']]
    return rows_missing.sort_values(by='num_cols_missing', ascending=False)

# %% [markdown]
# ## Let's Combine out Various Techniques into a single function:

# %%
def summarize(df):
    '''
    summarize will take in a single argument (a pandas dataframe) 
    and output to console various statistics on said dataframe, including:
    # .head()
    # .info()
    # .describe()
    # .value_counts()
    # observation of nulls in the dataframe
    '''
    print('SUMMARY REPORT')
    print('=====================================================\n\n')
    print('Dataframe head: ')
    print(df.head(3))
    print('=====================================================\n\n')
    print('Dataframe info: ')
    print(df.info())
    print('=====================================================\n\n')
    print('Dataframe Description: ')
    print(df.describe())
    num_cols = [col for col in df.columns if df[col].dtype != 'O']
    cat_cols = [col for col in df.columns if col not in num_cols]
    print('=====================================================')
    print('DataFrame value counts: ')
    for col in df.columns:
        if col in cat_cols:
            print(df[col].value_counts(), '\n')
        else:
            print(df[col].value_counts(bins=10, sort=False), '\n')
    print('=====================================================')
    print('nulls in dataframe by column: ')
    print(nulls_by_col(df))
    print('=====================================================')
    print('nulls in dataframe by row: ')
    print(nulls_by_row(df))
    print('=====================================================')

# %%
summarize(df)
# Out:
# SUMMARY REPORT
# =====================================================
#
#
# Dataframe head:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  14297519                    NaN                       NaN           NaN
# 1  17052889                    NaN                       NaN           NaN
# 2  14186244                    NaN                       NaN           NaN
#
#            bathroomcnt           bedroomcnt buildingclasstypeid  \
# 0                 3.50                 4.00                None
# 1                 1.00                 2.00                None
# 2                 2.00                 3.00                None
#
#    buildingqualitytypeid    calculatedbathnbr  decktypeid  ...  \
# 0                    NaN                 3.50         NaN  ...
# 1                    NaN                 1.00         NaN  ...
# 2                    NaN                 2.00         NaN  ...
#
#    structuretaxvaluedollarcnt    taxvaluedollarcnt       assessmentyear  \
# 0                  485,713.00         1,023,282.00             2,016.00
# 1                   88,000.00           464,000.00             2,016.00
# 2                   85,289.00           564,778.00             2,016.00
#
#   landtaxvaluedollarcnt            taxamount  taxdelinquencyflag  \
# 0            537,569.00            11,013.72                None
# 1            376,000.00             5,672.48                None
# 2            479,489.00             6,488.30                None
#
#    taxdelinquencyyear   censustractandblock             logerror  \
# 0                 NaN 60,590,630,072,012.00                 0.03
# 1                 NaN 61,110,010,023,006.00                 0.06
# 2                 NaN 60,590,218,022,012.00                 0.01
#
#    transactiondate
# 0       2017-01-01
# 1       2017-01-01
# 2       2017-01-01
#
# [3 rows x 60 columns]
# =====================================================
#
#
# Dataframe info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52441 entries, 0 to 52440
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      52441 non-null  int64
#  1   airconditioningtypeid         13638 non-null  float64
#  2   architecturalstyletypeid      70 non-null     float64
#  3   basementsqft                  47 non-null     float64
#  4   bathroomcnt                   52441 non-null  float64
#  5   bedroomcnt                    52441 non-null  float64
#  6   buildingclasstypeid           0 non-null      object
#  7   buildingqualitytypeid         33740 non-null  float64
#  8   calculatedbathnbr             52304 non-null  float64
#  9   decktypeid                    389 non-null    float64
#  10  finishedfloor1squarefeet      4381 non-null   float64
#  11  calculatedfinishedsquarefeet  52359 non-null  float64
#  12  finishedsquarefeet12          52194 non-null  float64
#  13  finishedsquarefeet13          0 non-null      object
#  14  finishedsquarefeet15          0 non-null      object
#  15  finishedsquarefeet50          4381 non-null   float64
#  16  finishedsquarefeet6           165 non-null    float64
#  17  fips                          52441 non-null  float64
#  18  fireplacecnt                  7243 non-null   float64
#  19  fullbathcnt                   52304 non-null  float64
#  20  garagecarcnt                  18015 non-null  float64
#  21  garagetotalsqft               18015 non-null  float64
#  22  hashottuborspa                1515 non-null   float64
#  23  heatingorsystemtypeid         33935 non-null  float64
#  24  latitude                      52441 non-null  float64
#  25  longitude                     52441 non-null  float64
#  26  lotsizesquarefeet             52072 non-null  float64
#  27  poolcnt                       11096 non-null  float64
#  28  poolsizesum                   867 non-null    float64
#  29  pooltypeid10                  444 non-null    float64
#  30  pooltypeid2                   1071 non-null   float64
#  31  pooltypeid7                   10009 non-null  float64
#  32  propertycountylandusecode     52441 non-null  object
#  33  propertylandusetypeid         52441 non-null  float64
#  34  propertyzoningdesc            33848 non-null  object
#  35  rawcensustractandblock        52441 non-null  float64
#  36  regionidcity                  51404 non-null  float64
#  37  regionidcounty                52441 non-null  float64
#  38  regionidneighborhood          19033 non-null  float64
#  39  regionidzip                   52415 non-null  float64
#  40  roomcnt                       52441 non-null  float64
#  41  storytypeid                   47 non-null     float64
#  42  threequarterbathnbr           6724 non-null   float64
#  43  typeconstructiontypeid        76 non-null     float64
#  44  unitcnt                       33847 non-null  float64
#  45  yardbuildingsqft17            1937 non-null   float64
#  46  yardbuildingsqft26            63 non-null     float64
#  47  yearbuilt                     52325 non-null  float64
#  48  numberofstories               14561 non-null  float64
#  49  fireplaceflag                 81 non-null     float64
#  50  structuretaxvaluedollarcnt    52357 non-null  float64
#  51  taxvaluedollarcnt             52440 non-null  float64
#  52  assessmentyear                52441 non-null  float64
#  53  landtaxvaluedollarcnt         52440 non-null  float64
#  54  taxamount                     52437 non-null  float64
#  55  taxdelinquencyflag            2079 non-null   object
#  56  taxdelinquencyyear            2079 non-null   float64
#  57  censustractandblock           52318 non-null  float64
#  58  logerror                      52441 non-null  float64
#  59  transactiondate               52441 non-null  object
# dtypes: float64(52), int64(1), object(7)
# memory usage: 24.0+ MB
# None
# =====================================================
#
#
# Dataframe Description:
#                   parcelid  airconditioningtypeid  architecturalstyletypeid  \
# count            52,441.00              13,638.00                     70.00
# mean         12,999,115.87                   2.44                      7.10
# std           3,411,444.02                   3.85                      2.67
# min          10,711,855.00                   1.00                      2.00
# 25%          11,510,217.00                   1.00                      7.00
# 50%          12,577,645.00                   1.00                      7.00
# 75%          14,129,530.00                   1.00                      7.00
# max         167,687,839.00                  13.00                     21.00
#
#               basementsqft          bathroomcnt           bedroomcnt  \
# count                47.00            52,441.00            52,441.00
# mean                678.98                 2.30                 3.30
# std                 711.83                 1.02                 0.95
# min                  38.00                 0.00                 0.00
# 25%                 263.50                 2.00                 3.00
# 50%                 512.00                 2.00                 3.00
# 75%                 809.50                 3.00                 4.00
# max               3,560.00                18.00                14.00
#
#        buildingqualitytypeid    calculatedbathnbr           decktypeid  \
# count              33,740.00            52,304.00               389.00
# mean                    6.26                 2.30                66.00
# std                     1.72                 1.02                 0.00
# min                     1.00                 1.00                66.00
# 25%                     5.00                 2.00                66.00
# 50%                     6.00                 2.00                66.00
# 75%                     8.00                 3.00                66.00
# max                    12.00                18.00                66.00
#
#        finishedfloor1squarefeet  ...      numberofstories  \
# count                  4,381.00  ...            14,561.00
# mean                   1,545.61  ...                 1.41
# std                      674.87  ...                 0.54
# min                      184.00  ...                 1.00
# 25%                    1,151.00  ...                 1.00
# 50%                    1,410.00  ...                 1.00
# 75%                    1,759.00  ...                 2.00
# max                    6,912.00  ...                 6.00
#
#              fireplaceflag  structuretaxvaluedollarcnt    taxvaluedollarcnt  \
# count                81.00                   52,357.00            52,440.00
# mean                  1.00                  196,533.75           529,688.16
# std                   0.00                  254,340.14           751,894.55
# min                   1.00                      129.00             1,000.00
# 25%                   1.00                   77,071.00           193,747.50
# 50%                   1.00                  131,811.00           373,612.00
# 75%                   1.00                  226,334.00           619,301.25
# max                   1.00                9,164,901.00        49,061,236.00
#
#             assessmentyear  landtaxvaluedollarcnt            taxamount  \
# count            52,441.00              52,440.00            52,437.00
# mean              2,016.00             333,465.48             6,453.51
# std                   0.00             570,527.80             8,755.57
# min               2,016.00                 161.00                49.18
# 25%               2,016.00              76,020.75             2,656.22
# 50%               2,016.00             218,032.00             4,647.74
# 75%               2,016.00             408,606.75             7,377.50
# max               2,016.00          48,952,198.00           586,639.30
#
#         taxdelinquencyyear    censustractandblock             logerror
# count             2,079.00              52,318.00            52,441.00
# mean                 14.10  60,502,401,189,819.98                 0.02
# std                   2.39   1,859,036,273,451.59                 0.18
# min                   4.00  60,371,011,101,000.00                -4.66
# 25%                  14.00  60,374,012,032,004.25                -0.02
# 50%                  15.00  60,376,203,011,013.50                 0.01
# 75%                  15.00  60,590,423,261,751.25                 0.04
# max                  99.00 483,030,105,084,015.00                 5.26
#
# [8 rows x 53 columns]
# =====================================================
# DataFrame value counts:
# (10554879.015, 26409453.4]    52421
# (26409453.4, 42107051.8]          0
# (42107051.8, 57804650.2]          0
# (57804650.2, 73502248.6]          0
# (73502248.6, 89199847.0]          1
# (89199847.0, 104897445.4]         0
# (104897445.4, 120595043.8]        0
# (120595043.8, 136292642.2]        0
# (136292642.2, 151990240.6]        0
# (151990240.6, 167687839.0]       19
# Name: parcelid, dtype: int64
#
# (0.987, 2.2]    11895
# (2.2, 3.4]          0
# (3.4, 4.6]          0
# (4.6, 5.8]        159
# (5.8, 7.0]          0
# (7.0, 8.2]          0
# (8.2, 9.4]          0
# (9.4, 10.6]         0
# (10.6, 11.8]       16
# (11.8, 13.0]     1568
# Name: airconditioningtypeid, dtype: int64
#
# (1.9800000000000002, 3.9]     5
# (3.9, 5.8]                    0
# (5.8, 7.7]                   62
# (7.7, 9.6]                    1
# (9.6, 11.5]                   0
# (11.5, 13.4]                  0
# (13.4, 15.3]                  0
# (15.3, 17.2]                  0
# (17.2, 19.1]                  0
# (19.1, 21.0]                  2
# Name: architecturalstyletypeid, dtype: int64
#
# (34.477000000000004, 390.2]    20
# (390.2, 742.4]                 13
# (742.4, 1094.6]                 7
# (1094.6, 1446.8]                3
# (1446.8, 1799.0]                0
# (1799.0, 2151.2]                2
# (2151.2, 2503.4]                0
# (2503.4, 2855.6]                0
# (2855.6, 3207.8]                1
# (3207.8, 3560.0]                1
# Name: basementsqft, dtype: int64
#
# (-0.019, 1.8]    10530
# (1.8, 3.6]       37418
# (3.6, 5.4]        3717
# (5.4, 7.2]         681
# (7.2, 9.0]          85
# (9.0, 10.8]          5
# (10.8, 12.6]         3
# (12.6, 14.4]         1
# (14.4, 16.2]         0
# (16.2, 18.0]         1
# Name: bathroomcnt, dtype: int64
#
# (-0.015, 1.4]      749
# (1.4, 2.8]        8340
# (2.8, 4.2]       38599
# (4.2, 5.6]        3973
# (5.6, 7.0]         741
# (7.0, 8.4]          24
# (8.4, 9.8]           8
# (9.8, 11.2]          3
# (11.2, 12.6]         3
# (12.6, 14.0]         1
# Name: bedroomcnt, dtype: int64
#
# Series([], Name: buildingclasstypeid, dtype: int64)
#
# (0.988, 2.1]       13
# (2.1, 3.2]        152
# (3.2, 4.3]       8156
# (4.3, 5.4]       1513
# (5.4, 6.5]      10289
# (6.5, 7.6]       3427
# (7.6, 8.7]       8244
# (8.7, 9.8]       1121
# (9.8, 10.9]       230
# (10.9, 12.0]      595
# Name: buildingqualitytypeid, dtype: int64
#
# (0.982, 2.7]    36221
# (2.7, 4.4]      13818
# (4.4, 6.1]       2035
# (6.1, 7.8]        151
# (7.8, 9.5]         69
# (9.5, 11.2]         8
# (11.2, 12.9]        0
# (12.9, 14.6]        1
# (14.6, 16.3]        0
# (16.3, 18.0]        1
# Name: calculatedbathnbr, dtype: int64
#
# (65.93299999999999, 65.947]      0
# (65.947, 65.96]                  0
# (65.96, 65.974]                  0
# (65.974, 65.987]                 0
# (65.987, 66.0]                 389
# (66.0, 66.013]                   0
# (66.013, 66.026]                 0
# (66.026, 66.04]                  0
# (66.04, 66.053]                  0
# (66.053, 66.066]                 0
# Name: decktypeid, dtype: int64
#
# (177.271, 856.8]     312
# (856.8, 1529.6]     2316
# (1529.6, 2202.4]    1266
# (2202.4, 2875.2]     276
# (2875.2, 3548.0]     123
# (3548.0, 4220.8]      43
# (4220.8, 4893.6]      24
# (4893.6, 5566.4]      12
# (5566.4, 6239.2]       5
# (6239.2, 6912.0]       4
# Name: finishedfloor1squarefeet, dtype: int64
#
# (106.198, 2308.1]     39298
# (2308.1, 4488.2]      11836
# (4488.2, 6668.3]       1004
# (6668.3, 8848.4]        160
# (8848.4, 11028.5]        42
# (11028.5, 13208.6]       12
# (13208.6, 15388.7]        2
# (15388.7, 17568.8]        2
# (17568.8, 19748.9]        1
# (19748.9, 21929.0]        2
# Name: calculatedfinishedsquarefeet, dtype: int64
#
# (106.198, 2308.1]     39149
# (2308.1, 4488.2]      11821
# (4488.2, 6668.3]       1003
# (6668.3, 8848.4]        160
# (8848.4, 11028.5]        42
# (11028.5, 13208.6]       12
# (13208.6, 15388.7]        2
# (15388.7, 17568.8]        2
# (17568.8, 19748.9]        1
# (19748.9, 21929.0]        2
# Name: finishedsquarefeet12, dtype: int64
#
# Series([], Name: finishedsquarefeet13, dtype: int64)
#
# Series([], Name: finishedsquarefeet15, dtype: int64)
#
# (171.716, 1412.3]     2185
# (1412.3, 2640.6]      1905
# (2640.6, 3868.9]       210
# (3868.9, 5097.2]        57
# (5097.2, 6325.5]        13
# (6325.5, 7553.8]         7
# (7553.8, 8782.1]         2
# (8782.1, 10010.4]        1
# (10010.4, 11238.7]       0
# (11238.7, 12467.0]       1
# Name: finishedsquarefeet50, dtype: int64
#
# (374.781, 901.8]    57
# (901.8, 1423.6]     72
# (1423.6, 1945.4]    16
# (1945.4, 2467.2]     8
# (2467.2, 2989.0]     4
# (2989.0, 3510.8]     3
# (3510.8, 4032.6]     2
# (4032.6, 4554.4]     2
# (4554.4, 5076.2]     0
# (5076.2, 5598.0]     1
# Name: finishedsquarefeet6, dtype: int64
#
# (6036.925, 6044.4]    33910
# (6044.4, 6051.8]          0
# (6051.8, 6059.2]      14136
# (6059.2, 6066.6]          0
# (6066.6, 6074.0]          0
# (6074.0, 6081.4]          0
# (6081.4, 6088.8]          0
# (6088.8, 6096.2]          0
# (6096.2, 6103.6]          0
# (6103.6, 6111.0]       4395
# Name: fips, dtype: int64
#
# (0.995, 1.4]    6031
# (1.4, 1.8]         0
# (1.8, 2.2]       945
# (2.2, 2.6]         0
# (2.6, 3.0]       229
# (3.0, 3.4]         0
# (3.4, 3.8]         0
# (3.8, 4.2]        35
# (4.2, 4.6]         0
# (4.6, 5.0]         3
# Name: fireplacecnt, dtype: int64
#
# (0.982, 2.7]    36233
# (2.7, 4.4]      14515
# (4.4, 6.1]       1381
# (6.1, 7.8]         96
# (7.8, 9.5]         69
# (9.5, 11.2]         8
# (11.2, 12.9]        0
# (12.9, 14.6]        1
# (14.6, 16.3]        0
# (16.3, 18.0]        1
# Name: fullbathcnt, dtype: int64
#
# (-0.015, 1.4]     2267
# (1.4, 2.8]       14802
# (2.8, 4.2]         875
# (4.2, 5.6]          45
# (5.6, 7.0]          16
# (7.0, 8.4]           2
# (8.4, 9.8]           2
# (9.8, 11.2]          4
# (11.2, 12.6]         0
# (12.6, 14.0]         2
# Name: garagecarcnt, dtype: int64
#
# (-4.252000000000001, 425.1]     4457
# (425.1, 850.2]                 13180
# (850.2, 1275.3]                  324
# (1275.3, 1700.4]                  38
# (1700.4, 2125.5]                   6
# (2125.5, 2550.6]                   2
# (2550.6, 2975.7]                   4
# (2975.7, 3400.8]                   2
# (3400.8, 3825.9]                   1
# (3825.9, 4251.0]                   1
# Name: garagetotalsqft, dtype: int64
#
# (0.9989, 0.9992]       0
# (0.9992, 0.9994]       0
# (0.9994, 0.9996]       0
# (0.9996, 0.9998]       0
# (0.9998, 1.0]       1515
# (1.0, 1.0002]          0
# (1.0002, 1.0004]       0
# (1.0004, 1.0006]       0
# (1.0006, 1.0008]       0
# (1.0008, 1.001]        0
# Name: hashottuborspa, dtype: int64
#
# (0.976, 3.3]    20743
# (3.3, 5.6]          0
# (5.6, 7.9]      13082
# (7.9, 10.2]         2
# (10.2, 12.5]        0
# (12.5, 14.8]       16
# (14.8, 17.1]        0
# (17.1, 19.4]        6
# (19.4, 21.7]       85
# (21.7, 24.0]        1
# Name: heatingorsystemtypeid, dtype: int64
#
# (33339141.852, 33488434.7]      761
# (33488434.7, 33636249.4]       3224
# (33636249.4, 33784064.1]       6087
# (33784064.1, 33931878.8]      10955
# (33931878.8, 34079693.5]       9065
# (34079693.5, 34227508.2]      12470
# (34227508.2, 34375322.9]       4619
# (34375322.9, 34523137.6]       1823
# (34523137.6, 34670952.3]       2187
# (34670952.3, 34818767.0]       1250
# Name: latitude, dtype: int64
#
# (-119477336.781, -119283338.0]      161
# (-119283338.0, -119091260.0]       1303
# (-119091260.0, -118899182.0]       1066
# (-118899182.0, -118707104.0]       1784
# (-118707104.0, -118515026.0]       3849
# (-118515026.0, -118322948.0]       9346
# (-118322948.0, -118130870.0]      10050
# (-118130870.0, -117938792.0]      11242
# (-117938792.0, -117746714.0]       9163
# (-117746714.0, -117554636.0]       4477
# Name: longitude, dtype: int64
#
# (-6734.775000000001, 697313.4]    52051
# (697313.4, 1394390.8]                10
# (1394390.8, 2091468.2]                2
# (2091468.2, 2788545.6]                1
# (2788545.6, 3485623.0]                1
# (3485623.0, 4182700.4]                0
# (4182700.4, 4879777.8]                0
# (4879777.8, 5576855.2]                0
# (5576855.2, 6273932.6]                0
# (6273932.6, 6971010.0]                7
# Name: lotsizesquarefeet, dtype: int64
#
# (0.9989, 0.9992]        0
# (0.9992, 0.9994]        0
# (0.9994, 0.9996]        0
# (0.9996, 0.9998]        0
# (0.9998, 1.0]       11096
# (1.0, 1.0002]           0
# (1.0002, 1.0004]        0
# (1.0004, 1.0006]        0
# (1.0006, 1.0008]        0
# (1.0008, 1.001]         0
# Name: poolcnt, dtype: int64
#
# (22.523, 171.6]       7
# (171.6, 319.2]       46
# (319.2, 466.8]      322
# (466.8, 614.4]      307
# (614.4, 762.0]      123
# (762.0, 909.6]       48
# (909.6, 1057.2]       7
# (1057.2, 1204.8]      5
# (1204.8, 1352.4]      0
# (1352.4, 1500.0]      2
# Name: poolsizesum, dtype: int64
#
# (0.9989, 0.9992]      0
# (0.9992, 0.9994]      0
# (0.9994, 0.9996]      0
# (0.9996, 0.9998]      0
# (0.9998, 1.0]       444
# (1.0, 1.0002]         0
# (1.0002, 1.0004]      0
# (1.0004, 1.0006]      0
# (1.0006, 1.0008]      0
# (1.0008, 1.001]       0
# Name: pooltypeid10, dtype: int64
#
# (0.9989, 0.9992]       0
# (0.9992, 0.9994]       0
# (0.9994, 0.9996]       0
# (0.9996, 0.9998]       0
# (0.9998, 1.0]       1071
# (1.0, 1.0002]          0
# (1.0002, 1.0004]       0
# (1.0004, 1.0006]       0
# (1.0006, 1.0008]       0
# (1.0008, 1.001]        0
# Name: pooltypeid2, dtype: int64
#
# (0.9989, 0.9992]        0
# (0.9992, 0.9994]        0
# (0.9994, 0.9996]        0
# (0.9996, 0.9998]        0
# (0.9998, 1.0]       10009
# (1.0, 1.0002]           0
# (1.0002, 1.0004]        0
# (1.0004, 1.0006]        0
# (1.0006, 1.0008]        0
# (1.0008, 1.001]         0
# Name: pooltypeid7, dtype: int64
#
# 0100    26782
# 122     13067
# 0101     6413
# 1111     3362
# 1        1069
# 1110     1025
# 0104      369
# 010G       94
# 0103       91
# 0108       57
# 010M       53
# 0109       18
# 1112        8
# 0110        6
# 0113        6
# 0141        4
# 0102        3
# 0105        3
# 010V        2
# 0111        2
# 0130        2
# 0131        1
# 0133        1
# 0115        1
# 010L        1
# 0114        1
# Name: propertycountylandusecode, dtype: int64
#
# (260.738, 260.791]        0
# (260.791, 260.843]        0
# (260.843, 260.896]        0
# (260.896, 260.948]        0
# (260.948, 261.0]      52441
# (261.0, 261.052]          0
# (261.052, 261.104]        0
# (261.104, 261.157]        0
# (261.157, 261.209]        0
# (261.209, 261.261]        0
# Name: propertylandusetypeid, dtype: int64
#
# LAR1          6498
# LARS          1385
# LBR1N         1111
# SCUR2          712
# LARE11         612
#               ...
# LCR3800015       1
# PSR6*            1
# LARE             1
# MYR3PY           1
# BFA15000*        1
# Name: propertyzoningdesc, Length: 1286, dtype: int64
#
# (60370272.019999996, 60444919.091]    33910
# (60444919.091, 60518827.081]              0
# (60518827.081, 60592735.071]          14136
# (60592735.071, 60666643.061]              0
# (60666643.061, 60740551.052]              0
# (60740551.052, 60814459.042]              0
# (60814459.042, 60888367.032]              0
# (60888367.032, 60962275.022]              0
# (60962275.022, 61036183.012]              0
# (61036183.012, 61110091.002]           4395
# Name: rawcensustractandblock, dtype: int64
#
# (3097.9339999999997, 42797.5]    39166
# (42797.5, 82104.0]               10609
# (82104.0, 121410.5]                828
# (121410.5, 160717.0]                 0
# (160717.0, 200023.5]                 0
# (200023.5, 239330.0]                 0
# (239330.0, 278636.5]                17
# (278636.5, 317943.0]                 0
# (317943.0, 357249.5]                 0
# (357249.5, 396556.0]               784
# Name: regionidcity, dtype: int64
#
# (1284.184, 1467.5]    14136
# (1467.5, 1649.0]          0
# (1649.0, 1830.5]          0
# (1830.5, 2012.0]          0
# (2012.0, 2193.5]       4395
# (2193.5, 2375.0]          0
# (2375.0, 2556.5]          0
# (2556.5, 2738.0]          0
# (2738.0, 2919.5]          0
# (2919.5, 3101.0]      33910
# Name: regionidcounty, dtype: int64
#
# (6194.784, 82673.5]     7268
# (82673.5, 158395.0]     3001
# (158395.0, 234116.5]      33
# (234116.5, 309838.0]    7154
# (309838.0, 385559.5]       7
# (385559.5, 461281.0]     925
# (461281.0, 537002.5]       0
# (537002.5, 612724.0]       0
# (612724.0, 688445.5]      66
# (688445.5, 764167.0]     579
# Name: regionidneighborhood, dtype: int64
#
# (95678.306, 126351.3]    52403
# (126351.3, 156720.6]         0
# (156720.6, 187089.9]         0
# (187089.9, 217459.2]         0
# (217459.2, 247828.5]         0
# (247828.5, 278197.8]         0
# (278197.8, 308567.1]         0
# (308567.1, 338936.4]         0
# (338936.4, 369305.7]         0
# (369305.7, 399675.0]        12
# Name: regionidzip, dtype: int64
#
# (-0.016, 1.5]    37854
# (1.5, 3.0]          91
# (3.0, 4.5]         521
# (4.5, 6.0]        5872
# (6.0, 7.5]        3615
# (7.5, 9.0]        3989
# (9.0, 10.5]        339
# (10.5, 12.0]       143
# (12.0, 13.5]        10
# (13.5, 15.0]         7
# Name: roomcnt, dtype: int64
#
# (6.992, 6.994]     0
# (6.994, 6.996]     0
# (6.996, 6.997]     0
# (6.997, 6.999]     0
# (6.999, 7.0]      47
# (7.0, 7.001]       0
# (7.001, 7.003]     0
# (7.003, 7.004]     0
# (7.004, 7.006]     0
# (7.006, 7.007]     0
# Name: storytypeid, dtype: int64
#
# (0.993, 1.6]    6645
# (1.6, 2.2]        70
# (2.2, 2.8]         0
# (2.8, 3.4]         8
# (3.4, 4.0]         0
# (4.0, 4.6]         0
# (4.6, 5.2]         0
# (5.2, 5.8]         0
# (5.8, 6.4]         0
# (6.4, 7.0]         1
# Name: threequarterbathnbr, dtype: int64
#
# (3.9970000000000003, 4.2]     1
# (4.2, 4.4]                    0
# (4.4, 4.6]                    0
# (4.6, 4.8]                    0
# (4.8, 5.0]                    0
# (5.0, 5.2]                    0
# (5.2, 5.4]                    0
# (5.4, 5.6]                    0
# (5.6, 5.8]                    0
# (5.8, 6.0]                   75
# Name: typeconstructiontypeid, dtype: int64
#
# (0.997, 1.2]    33817
# (1.2, 1.4]          0
# (1.4, 1.6]          0
# (1.6, 1.8]          0
# (1.8, 2.0]         29
# (2.0, 2.2]          0
# (2.2, 2.4]          0
# (2.4, 2.6]          0
# (2.6, 2.8]          0
# (2.8, 3.0]          1
# Name: unitcnt, dtype: int64
#
# (7.819, 329.0]      1219
# (329.0, 647.0]       571
# (647.0, 965.0]        95
# (965.0, 1283.0]       35
# (1283.0, 1601.0]       9
# (1601.0, 1919.0]       1
# (1919.0, 2237.0]       2
# (2237.0, 2555.0]       2
# (2555.0, 2873.0]       1
# (2873.0, 3191.0]       2
# Name: yardbuildingsqft17, dtype: int64
#
# (11.143, 97.6]    19
# (97.6, 183.2]     13
# (183.2, 268.8]    10
# (268.8, 354.4]     7
# (354.4, 440.0]     4
# (440.0, 525.6]     6
# (525.6, 611.2]     1
# (611.2, 696.8]     1
# (696.8, 782.4]     1
# (782.4, 868.0]     1
# Name: yardbuildingsqft26, dtype: int64
#
# (1877.861, 1891.8]       22
# (1891.8, 1905.6]        169
# (1905.6, 1919.4]       1034
# (1919.4, 1933.2]       4095
# (1933.2, 1947.0]       4905
# (1947.0, 1960.8]      15935
# (1960.8, 1974.6]      10229
# (1974.6, 1988.4]       6949
# (1988.4, 2002.2]       5925
# (2002.2, 2016.0]       3062
# Name: yearbuilt, dtype: int64
#
# (0.994, 1.5]    8890
# (1.5, 2.0]      5318
# (2.0, 2.5]         0
# (2.5, 3.0]       352
# (3.0, 3.5]         0
# (3.5, 4.0]         0
# (4.0, 4.5]         0
# (4.5, 5.0]         0
# (5.0, 5.5]         0
# (5.5, 6.0]         1
# Name: numberofstories, dtype: int64
#
# (0.9989, 0.9992]     0
# (0.9992, 0.9994]     0
# (0.9994, 0.9996]     0
# (0.9996, 0.9998]     0
# (0.9998, 1.0]       81
# (1.0, 1.0002]        0
# (1.0002, 1.0004]     0
# (1.0004, 1.0006]     0
# (1.0006, 1.0008]     0
# (1.0008, 1.001]      0
# Name: fireplaceflag, dtype: int64
#
# (-9035.773000000001, 916606.2]    51421
# (916606.2, 1833083.4]               770
# (1833083.4, 2749560.6]              105
# (2749560.6, 3666037.8]               38
# (3666037.8, 4582515.0]                8
# (4582515.0, 5498992.2]                7
# (5498992.2, 6415469.4]                2
# (6415469.4, 7331946.6]                1
# (7331946.6, 8248423.8]                4
# (8248423.8, 9164901.0]                1
# Name: structuretaxvaluedollarcnt, dtype: int64
#
# (-48060.236999999994, 4907023.6]    52230
# (4907023.6, 9813047.2]                173
# (9813047.2, 14719070.8]                23
# (14719070.8, 19625094.4]                8
# (19625094.4, 24531118.0]                4
# (24531118.0, 29437141.6]                1
# (29437141.6, 34343165.2]                0
# (34343165.2, 39249188.8]                0
# (39249188.8, 44155212.4]                0
# (44155212.4, 49061236.0]                1
# Name: taxvaluedollarcnt, dtype: int64
#
# (2013.983, 2014.387]        0
# (2014.387, 2014.79]         0
# (2014.79, 2015.194]         0
# (2015.194, 2015.597]        0
# (2015.597, 2016.0]      52441
# (2016.0, 2016.403]          0
# (2016.403, 2016.806]        0
# (2016.806, 2017.21]         0
# (2017.21, 2017.613]         0
# (2017.613, 2018.016]        0
# Name: assessmentyear, dtype: int64
#
# (-48791.03799999999, 4895364.7]    52334
# (4895364.7, 9790568.4]                86
# (9790568.4, 14685772.1]               13
# (14685772.1, 19580975.8]               5
# (19580975.8, 24476179.5]               1
# (24476179.5, 29371383.2]               0
# (29371383.2, 34266586.9]               0
# (34266586.9, 39161790.6]               0
# (39161790.6, 44056994.3]               0
# (44056994.3, 48952198.0]               1
# Name: landtaxvaluedollarcnt, dtype: int64
#
# (-537.411, 58708.192]       52238
# (58708.192, 117367.204]       166
# (117367.204, 176026.216]       19
# (176026.216, 234685.228]        9
# (234685.228, 293344.24]         4
# (293344.24, 352003.252]         0
# (352003.252, 410662.264]        0
# (410662.264, 469321.276]        0
# (469321.276, 527980.288]        0
# (527980.288, 586639.3]          1
# Name: taxamount, dtype: int64
#
# Y    2079
# Name: taxdelinquencyflag, dtype: int64
#
# (3.904, 13.5]     387
# (13.5, 23.0]     1691
# (23.0, 32.5]        0
# (32.5, 42.0]        0
# (42.0, 51.5]        0
# (51.5, 61.0]        0
# (61.0, 70.5]        0
# (70.5, 80.0]        0
# (80.0, 89.5]        0
# (89.5, 99.0]        1
# Name: taxdelinquencyyear, dtype: int64
#
# (59948352007016.984, 102636920499301.5]    52317
# (102636920499301.5, 144902829897603.0]         0
# (144902829897603.0, 187168739295904.5]         0
# (187168739295904.5, 229434648694206.03]        0
# (229434648694206.03, 271700558092507.5]        0
# (271700558092507.5, 313966467490809.0]         0
# (313966467490809.0, 356232376889110.5]         0
# (356232376889110.5, 398498286287411.94]        0
# (398498286287411.94, 440764195685713.5]        0
# (440764195685713.5, 483030105084015.0]         1
# Name: censustractandblock, dtype: int64
#
# (-4.666, -3.664]        2
# (-3.664, -2.672]        0
# (-2.672, -1.68]        26
# (-1.68, -0.688]       109
# (-0.688, 0.304]     50948
# (0.304, 1.296]       1221
# (1.296, 2.287]         76
# (2.287, 3.279]         57
# (3.279, 4.271]          1
# (4.271, 5.263]          1
# Name: logerror, dtype: int64
#
# 2017-06-30    810
# 2017-04-28    617
# 2017-05-31    566
# 2017-07-28    546
# 2017-08-31    528
#              ...
# 2017-05-07      1
# 2017-05-13      1
# 2017-05-20      1
# 2017-06-11      1
# 2017-09-25      1
# Name: transactiondate, Length: 257, dtype: int64
#
# =====================================================
# nulls in dataframe by column:
#                               num_rows_missing  percent_rows_missing
# finishedsquarefeet15                     52441                100.00
# buildingclasstypeid                      52441                100.00
# finishedsquarefeet13                     52441                100.00
# storytypeid                              52394                 99.91
# basementsqft                             52394                 99.91
# yardbuildingsqft26                       52378                 99.88
# architecturalstyletypeid                 52371                 99.87
# typeconstructiontypeid                   52365                 99.86
# fireplaceflag                            52360                 99.85
# finishedsquarefeet6                      52276                 99.69
# decktypeid                               52052                 99.26
# pooltypeid10                             51997                 99.15
# poolsizesum                              51574                 98.35
# pooltypeid2                              51370                 97.96
# hashottuborspa                           50926                 97.11
# yardbuildingsqft17                       50504                 96.31
# taxdelinquencyyear                       50362                 96.04
# taxdelinquencyflag                       50362                 96.04
# finishedfloor1squarefeet                 48060                 91.65
# finishedsquarefeet50                     48060                 91.65
# threequarterbathnbr                      45717                 87.18
# fireplacecnt                             45198                 86.19
# pooltypeid7                              42432                 80.91
# poolcnt                                  41345                 78.84
# airconditioningtypeid                    38803                 73.99
# numberofstories                          37880                 72.23
# garagecarcnt                             34426                 65.65
# garagetotalsqft                          34426                 65.65
# regionidneighborhood                     33408                 63.71
# buildingqualitytypeid                    18701                 35.66
# unitcnt                                  18594                 35.46
# propertyzoningdesc                       18593                 35.46
# heatingorsystemtypeid                    18506                 35.29
# regionidcity                              1037                  1.98
# lotsizesquarefeet                          369                  0.70
# finishedsquarefeet12                       247                  0.47
# fullbathcnt                                137                  0.26
# calculatedbathnbr                          137                  0.26
# censustractandblock                        123                  0.23
# yearbuilt                                  116                  0.22
# structuretaxvaluedollarcnt                  84                  0.16
# calculatedfinishedsquarefeet                82                  0.16
# regionidzip                                 26                  0.05
# taxamount                                    4                  0.01
# taxvaluedollarcnt                            1                  0.00
# landtaxvaluedollarcnt                        1                  0.00
# logerror                                     0                  0.00
# assessmentyear                               0                  0.00
# parcelid                                     0                  0.00
# roomcnt                                      0                  0.00
# regionidcounty                               0                  0.00
# rawcensustractandblock                       0                  0.00
# propertylandusetypeid                        0                  0.00
# propertycountylandusecode                    0                  0.00
# longitude                                    0                  0.00
# latitude                                     0                  0.00
# fips                                         0                  0.00
# bedroomcnt                                   0                  0.00
# bathroomcnt                                  0                  0.00
# transactiondate                              0                  0.00
# =====================================================
# nulls in dataframe by row:
#         parcelid  num_cols_missing  percent_cols_missing
# 28116  167687839                42                 70.00
# 9001   167686999                42                 70.00
# 41468   17188862                41                 68.33
# 13429   14460039                40                 66.67
# 48597   14341510                39                 65.00
# ...          ...               ...                   ...
# 42219   17292665                20                 33.33
# 21757   17194590                20                 33.33
# 20841   17270021                20                 33.33
# 10432   17097816                19                 31.67
# 12733   17215105                19                 31.67
#
# [52441 rows x 3 columns]
# =====================================================

# %% [markdown]
# ## Okay we summarized, now what?

# %%
def remove_columns(df, cols_to_remove):
    df = df.drop(columns=cols_to_remove)
    return df

# %%
def handle_missing_values(df, prop_required_columns=0.5, prop_required_row=0.75):
    threshold = int(round(prop_required_columns * len(df.index), 0))
    df = df.dropna(axis=1, thresh=threshold) #1, or ‘columns’ : Drop columns which contain missing value
    threshold = int(round(prop_required_row * len(df.columns), 0))
    df = df.dropna(axis=0, thresh=threshold) #0, or ‘index’ : Drop rows which contain missing values.
    return df

# %%
# combining everything in a cleaning function:
def data_prep(df, cols_to_remove=[], prop_required_column=0.5, prop_required_row=0.75):
    df = remove_columns(df, cols_to_remove)
    df = handle_missing_values(df, prop_required_column, prop_required_row)
    return df

# %%
df = data_prep(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52376 entries, 0 to 52440
# Data columns (total 31 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      52376 non-null  int64
#  1   bathroomcnt                   52376 non-null  float64
#  2   bedroomcnt                    52376 non-null  float64
#  3   buildingqualitytypeid         33740 non-null  float64
#  4   calculatedbathnbr             52304 non-null  float64
#  5   calculatedfinishedsquarefeet  52359 non-null  float64
#  6   finishedsquarefeet12          52194 non-null  float64
#  7   fips                          52376 non-null  float64
#  8   fullbathcnt                   52304 non-null  float64
#  9   heatingorsystemtypeid         33935 non-null  float64
#  10  latitude                      52376 non-null  float64
#  11  longitude                     52376 non-null  float64
#  12  lotsizesquarefeet             52016 non-null  float64
#  13  propertycountylandusecode     52376 non-null  object
#  14  propertylandusetypeid         52376 non-null  float64
#  15  propertyzoningdesc            33837 non-null  object
#  16  rawcensustractandblock        52376 non-null  float64
#  17  regionidcity                  51345 non-null  float64
#  18  regionidcounty                52376 non-null  float64
#  19  regionidzip                   52353 non-null  float64
#  20  roomcnt                       52376 non-null  float64
#  21  unitcnt                       33847 non-null  float64
#  22  yearbuilt                     52325 non-null  float64
#  23  structuretaxvaluedollarcnt    52300 non-null  float64
#  24  taxvaluedollarcnt             52375 non-null  float64
#  25  assessmentyear                52376 non-null  float64
#  26  landtaxvaluedollarcnt         52375 non-null  float64
#  27  taxamount                     52372 non-null  float64
#  28  censustractandblock           52262 non-null  float64
#  29  logerror                      52376 non-null  float64
#  30  transactiondate               52376 non-null  object
# dtypes: float64(27), int64(1), object(3)
# memory usage: 12.8+ MB

# %% [markdown]
# ## Handling Outliers
# - Note your use case
# - z-score: appropriate for normal data (normally distributed)
# - Tukey IQR method: not contingent on normality
#
# ### Tukey Interquartile Range (IQR) Method:
# - Calculate IQR
#     - Get Q3 and Q1
#     - Get difference (q3-q1)
#     - Establish "fences":
#         - Standard inner fence: k = 1.5
#         - Standard outer fence: k = 3.0
#         - Upper bound: q3 + k * IQR
#         - Lower bound: q1 - k * IQR

# %%
def get_upper_outliers(s, k=1.5):
    '''
    Given a series and a cutoff value, k, returns the upper outliers for the
    series.

    The values returned will be either 0 (if the point is not an outlier), or a
    number that indicates how far away from the upper bound the observation is.
    '''
    q1, q3 = s.quantile([.25, 0.75])
    iqr = q3 - q1
    upper_bound = q3 + k * iqr
    return s.apply(lambda x: max([x - upper_bound, 0]))

# %%
def add_upper_outlier_columns(df, k=1.5):
    '''
    Add a column with the suffix _outliers for all the numeric columns
    in the given dataframe.
    '''
    for col in df.select_dtypes('number'):
        df[col + '_outliers_upper'] = get_upper_outliers(df[col], k)
    return df

# %%
df = add_upper_outlier_columns(df)

# %%
df.head(20)
# Out:
#     parcelid          bathroomcnt           bedroomcnt  buildingqualitytypeid  \
# 0   14297519                 3.50                 4.00                    NaN
# 1   17052889                 1.00                 2.00                    NaN
# 2   14186244                 2.00                 3.00                    NaN
# 3   12177905                 3.00                 4.00                   8.00
# 4   12095076                 3.00                 4.00                   9.00
# 5   12069064                 1.00                 2.00                   5.00
# 6   12790562                 3.00                 4.00                   9.00
# 7   11104527                 3.00                 4.00                   8.00
# 8   13944538                 2.50                 3.00                    NaN
# 9   17110996                 2.50                 3.00                    NaN
# 10  14375300                 2.00                 4.00                    NaN
# 11  11830315                 1.00                 2.00                   4.00
# 12  14387959                 2.50                 3.00                    NaN
# 13  14349322                 2.50                 3.00                    NaN
# 14  11706737                 1.00                 2.00                   5.00
# 15  12531488                 1.00                 3.00                   4.00
# 16  14314879                 4.50                 6.00                    NaN
# 17  11130689                 2.00                 3.00                   6.00
# 18  12036177                 2.00                 3.00                   4.00
# 19  14333888                 3.00                 2.00                    NaN
#
#       calculatedbathnbr  calculatedfinishedsquarefeet  finishedsquarefeet12  \
# 0                  3.50                      3,100.00              3,100.00
# 1                  1.00                      1,465.00              1,465.00
# 2                  2.00                      1,243.00              1,243.00
# 3                  3.00                      2,376.00              2,376.00
# 4                  3.00                      2,962.00              2,962.00
# 5                  1.00                        738.00                738.00
# 6                  3.00                      3,039.00              3,039.00
# 7                  3.00                      2,540.00              2,540.00
# 8                  2.50                      1,340.00              1,340.00
# 9                  2.50                      1,371.00              1,371.00
# 10                 2.00                      1,677.00              1,677.00
# 11                 1.00                      1,146.00              1,146.00
# 12                 2.50                      2,074.00              2,074.00
# 13                 2.50                      2,018.00              2,018.00
# 14                 1.00                      1,316.00              1,316.00
# 15                 1.00                      1,641.00              1,641.00
# 16                 4.50                      3,870.00              3,870.00
# 17                 2.00                      1,538.00              1,538.00
# 18                 2.00                      1,851.00              1,851.00
# 19                 3.00                      3,230.00              3,230.00
#
#                    fips          fullbathcnt  heatingorsystemtypeid  ...  \
# 0              6,059.00                 3.00                    NaN  ...
# 1              6,111.00                 1.00                    NaN  ...
# 2              6,059.00                 2.00                    NaN  ...
# 3              6,037.00                 3.00                   2.00  ...
# 4              6,037.00                 3.00                   2.00  ...
# 5              6,037.00                 1.00                    NaN  ...
# 6              6,037.00                 3.00                   2.00  ...
# 7              6,037.00                 3.00                   2.00  ...
# 8              6,059.00                 2.00                    NaN  ...
# 9              6,111.00                 2.00                    NaN  ...
# 10             6,059.00                 2.00                    NaN  ...
# 11             6,037.00                 1.00                   7.00  ...
# 12             6,059.00                 2.00                    NaN  ...
# 13             6,059.00                 2.00                    NaN  ...
# 14             6,037.00                 1.00                    NaN  ...
# 15             6,037.00                 1.00                   7.00  ...
# 16             6,059.00                 4.00                    NaN  ...
# 17             6,037.00                 2.00                   2.00  ...
# 18             6,037.00                 2.00                   7.00  ...
# 19             6,059.00                 3.00                    NaN  ...
#
#     roomcnt_outliers_upper  unitcnt_outliers_upper  yearbuilt_outliers_upper  \
# 0                     0.00                     NaN                      0.00
# 1                     0.00                     NaN                      0.00
# 2                     0.00                     NaN                      0.00
# 3                     0.00                    0.00                      0.00
# 4                     0.00                    0.00                      0.00
# 5                     0.00                    0.00                      0.00
# 6                     0.00                    0.00                      0.00
# 7                     0.00                    0.00                      0.00
# 8                     0.00                     NaN                      0.00
# 9                     0.00                     NaN                      0.00
# 10                    0.00                     NaN                      0.00
# 11                    0.00                    0.00                      0.00
# 12                    0.00                     NaN                      0.00
# 13                    0.00                     NaN                      0.00
# 14                    0.00                    0.00                      0.00
# 15                    0.00                    0.00                      0.00
# 16                    0.00                     NaN                      0.00
# 17                    0.00                    0.00                      0.00
# 18                    0.00                    0.00                      0.00
# 19                    0.00                     NaN                      0.00
#
#    structuretaxvaluedollarcnt_outliers_upper  \
# 0                                  36,255.38
# 1                                       0.00
# 2                                       0.00
# 3                                       0.00
# 4                                       0.00
# 5                                       0.00
# 6                                       0.00
# 7                                       0.00
# 8                                       0.00
# 9                                       0.00
# 10                                      0.00
# 11                                      0.00
# 12                                      0.00
# 13                                      0.00
# 14                                      0.00
# 15                                      0.00
# 16                                      0.00
# 17                                      0.00
# 18                                      0.00
# 19                                      0.00
#
#     taxvaluedollarcnt_outliers_upper assessmentyear_outliers_upper  \
# 0                               0.00                          0.00
# 1                               0.00                          0.00
# 2                               0.00                          0.00
# 3                               0.00                          0.00
# 4                               0.00                          0.00
# 5                               0.00                          0.00
# 6                               0.00                          0.00
# 7                               0.00                          0.00
# 8                               0.00                          0.00
# 9                               0.00                          0.00
# 10                              0.00                          0.00
# 11                              0.00                          0.00
# 12                              0.00                          0.00
# 13                              0.00                          0.00
# 14                              0.00                          0.00
# 15                              0.00                          0.00
# 16                        784,111.75                          0.00
# 17                              0.00                          0.00
# 18                              0.00                          0.00
# 19                              0.00                          0.00
#
#     landtaxvaluedollarcnt_outliers_upper  taxamount_outliers_upper  \
# 0                                   0.00                      0.00
# 1                                   0.00                      0.00
# 2                                   0.00                      0.00
# 3                                   0.00                      0.00
# 4                                   0.00                      0.00
# 5                                   0.00                      0.00
# 6                                   0.00                      0.00
# 7                                   0.00                      0.00
# 8                                   0.00                      0.00
# 9                                   0.00                      0.00
# 10                                  0.00                      0.00
# 11                                  0.00                      0.00
# 12                                  0.00                      0.00
# 13                                  0.00                      0.00
# 14                                  0.00                      0.00
# 15                                  0.00                      0.00
# 16                            835,644.00                  7,313.65
# 17                                  0.00                      0.00
# 18                                  0.00                      0.00
# 19                                  0.00                      0.00
#
#     censustractandblock_outliers_upper  logerror_outliers_upper
# 0                                 0.00                     0.00
# 1                   194,969,941,974.00                     0.00
# 2                                 0.00                     0.00
# 3                                 0.00                     0.00
# 4                                 0.00                     0.00
# 5                                 0.00                     0.00
# 6                                 0.00                     0.00
# 7                                 0.00                     0.00
# 8                                 0.00                     0.00
# 9                   195,009,960,131.00                     0.00
# 10                                0.00                     0.00
# 11                                0.00                     0.00
# 12                                0.00                     0.00
# 13                                0.00                     0.00
# 14                                0.00                     0.00
# 15                                0.00                     0.00
# 16                                0.00                     0.00
# 17                                0.00                     0.00
# 18                                0.00                     0.07
# 19                                0.00                     0.00
#
# [20 rows x 59 columns]

# %%
outlier_cols = [col for col in df.columns if col.endswith('_outliers_upper')]
for col in outlier_cols:
    print(col, ': ')
    subset = df[col][df[col] > 0]
    print(f'Number of Observations Above Upper Bound: {subset.count()}', '\n')
    print(subset.describe())
    print('------', '\n')
# Out:
# parcelid_outliers_upper :
# Number of Observations Above Upper Bound: 18
#
# count                  18.00
# mean          143,394,163.60
# std            20,527,660.38
# min            61,585,397.88
# 25%           144,905,558.38
# 50%           149,581,311.38
# 75%           149,581,634.62
# max           149,584,059.88
# Name: parcelid_outliers_upper, dtype: float64
# ------
#
# bathroomcnt_outliers_upper :
# Number of Observations Above Upper Bound: 1579
#
# count               1,579.00
# mean                    1.14
# std                     0.97
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                    13.50
# Name: bathroomcnt_outliers_upper, dtype: float64
# ------
#
# bedroomcnt_outliers_upper :
# Number of Observations Above Upper Bound: 780
#
# count                 780.00
# mean                    0.78
# std                     0.75
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     0.50
# max                     8.50
# Name: bedroomcnt_outliers_upper, dtype: float64
# ------
#
# buildingqualitytypeid_outliers_upper :
# Number of Observations Above Upper Bound: 0
#
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: buildingqualitytypeid_outliers_upper, dtype: float64
# ------
#
# calculatedbathnbr_outliers_upper :
# Number of Observations Above Upper Bound: 1578
#
# count               1,578.00
# mean                    1.14
# std                     0.97
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                    13.50
# Name: calculatedbathnbr_outliers_upper, dtype: float64
# ------
#
# calculatedfinishedsquarefeet_outliers_upper :
# Number of Observations Above Upper Bound: 2276
#
# count               2,276.00
# mean                1,184.62
# std                 1,488.43
# min                     1.00
# 25%                   262.75
# 50%                   695.00
# 75%                 1,532.25
# max                18,066.00
# Name: calculatedfinishedsquarefeet_outliers_upper, dtype: float64
# ------
#
# finishedsquarefeet12_outliers_upper :
# Number of Observations Above Upper Bound: 2265
#
# count               2,265.00
# mean                1,187.36
# std                 1,490.09
# min                     1.00
# 25%                   265.00
# 50%                   697.00
# 75%                 1,535.00
# max                18,064.00
# Name: finishedsquarefeet12_outliers_upper, dtype: float64
# ------
#
# fips_outliers_upper :
# Number of Observations Above Upper Bound: 4383
#
# count               4,383.00
# mean                   19.00
# std                     0.00
# min                    19.00
# 25%                    19.00
# 50%                    19.00
# 75%                    19.00
# max                    19.00
# Name: fips_outliers_upper, dtype: float64
# ------
#
# fullbathcnt_outliers_upper :
# Number of Observations Above Upper Bound: 1556
#
# count               1,556.00
# mean                    1.04
# std                     0.97
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                    13.50
# Name: fullbathcnt_outliers_upper, dtype: float64
# ------
#
# heatingorsystemtypeid_outliers_upper :
# Number of Observations Above Upper Bound: 92
#
# count                  92.00
# mean                    5.41
# std                     0.66
# min                     3.50
# 25%                     5.50
# 50%                     5.50
# 75%                     5.50
# max                     9.50
# Name: heatingorsystemtypeid_outliers_upper, dtype: float64
# ------
#
# latitude_outliers_upper :
# Number of Observations Above Upper Bound: 36
#
# count                  36.00
# mean               35,110.18
# std                24,552.62
# min                    47.12
# 25%                18,829.38
# 50%                28,850.62
# 75%                50,029.62
# max                91,441.12
# Name: latitude_outliers_upper, dtype: float64
# ------
#
# longitude_outliers_upper :
# Number of Observations Above Upper Bound: 0
#
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: longitude_outliers_upper, dtype: float64
# ------
#
# lotsizesquarefeet_outliers_upper :
# Number of Observations Above Upper Bound: 5547
#
# count               5,547.00
# mean               35,576.37
# std               262,119.32
# min                     1.00
# 25%                 3,212.00
# 50%                 7,417.00
# 75%                22,272.00
# max             6,957,419.00
# Name: lotsizesquarefeet_outliers_upper, dtype: float64
# ------
#
# propertylandusetypeid_outliers_upper :
# Number of Observations Above Upper Bound: 0
#
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: propertylandusetypeid_outliers_upper, dtype: float64
# ------
#
# rawcensustractandblock_outliers_upper :
# Number of Observations Above Upper Bound: 4383
#
# count               4,383.00
# mean              195,012.55
# std                    25.19
# min               194,961.87
# 25%               194,990.87
# 50%               195,017.89
# 75%               195,034.97
# max               195,050.87
# Name: rawcensustractandblock_outliers_upper, dtype: float64
# ------
#
# regionidcity_outliers_upper :
# Number of Observations Above Upper Bound: 1629
#
# count               1,629.00
# mean              171,423.37
# std               138,591.84
# min                31,515.00
# 25%                36,328.00
# 50%                37,097.00
# 75%               314,157.00
# max               314,659.00
# Name: regionidcity_outliers_upper, dtype: float64
# ------
#
# regionidcounty_outliers_upper :
# Number of Observations Above Upper Bound: 0
#
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: regionidcounty_outliers_upper, dtype: float64
# ------
#
# regionidzip_outliers_upper :
# Number of Observations Above Upper Bound: 12
#
# count                  12.00
# mean              301,496.50
# std                     0.00
# min               301,496.50
# 25%               301,496.50
# 50%               301,496.50
# 75%               301,496.50
# max               301,496.50
# Name: regionidzip_outliers_upper, dtype: float64
# ------
#
# roomcnt_outliers_upper :
# Number of Observations Above Upper Bound: 17
#
# count                  17.00
# mean                    0.97
# std                     0.62
# min                     0.50
# 25%                     0.50
# 50%                     0.50
# 75%                     1.50
# max                     2.50
# Name: roomcnt_outliers_upper, dtype: float64
# ------
#
# unitcnt_outliers_upper :
# Number of Observations Above Upper Bound: 30
#
# count                  30.00
# mean                    1.03
# std                     0.18
# min                     1.00
# 25%                     1.00
# 50%                     1.00
# 75%                     1.00
# max                     2.00
# Name: unitcnt_outliers_upper, dtype: float64
# ------
#
# yearbuilt_outliers_upper :
# Number of Observations Above Upper Bound: 0
#
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: yearbuilt_outliers_upper, dtype: float64
# ------
#
# structuretaxvaluedollarcnt_outliers_upper :
# Number of Observations Above Upper Bound: 3891
#
# count               3,891.00
# mean              363,659.34
# std               573,977.54
# min                    54.38
# 25%                70,897.38
# 50%               182,784.38
# 75%               433,441.88
# max             8,715,443.38
# Name: structuretaxvaluedollarcnt_outliers_upper, dtype: float64
# ------
#
# taxvaluedollarcnt_outliers_upper :
# Number of Observations Above Upper Bound: 3518
#
# count               3,518.00
# mean            1,095,757.38
# std             1,938,701.52
# min                   619.75
# 25%               212,149.75
# 50%               532,114.75
# 75%             1,239,488.00
# max            47,805,347.75
# Name: taxvaluedollarcnt_outliers_upper, dtype: float64
# ------
#
# assessmentyear_outliers_upper :
# Number of Observations Above Upper Bound: 0
#
# count                   0.00
# mean                     NaN
# std                      NaN
# min                      NaN
# 25%                      NaN
# 50%                      NaN
# 75%                      NaN
# max                      NaN
# Name: assessmentyear_outliers_upper, dtype: float64
# ------
#
# landtaxvaluedollarcnt_outliers_upper :
# Number of Observations Above Upper Bound: 3007
#
# count               3,007.00
# mean              856,519.26
# std             1,670,816.68
# min                   517.00
# 25%               154,386.50
# 50%               414,914.00
# 75%               931,893.00
# max            48,046,105.00
# Name: landtaxvaluedollarcnt_outliers_upper, dtype: float64
# ------
#
# taxamount_outliers_upper :
# Number of Observations Above Upper Bound: 3794
#
# count               3,794.00
# mean               12,173.00
# std                22,125.17
# min                     1.03
# 25%                 2,284.42
# 50%                 5,828.40
# 75%                13,629.90
# max               572,194.69
# Name: taxamount_outliers_upper, dtype: float64
# ------
#
# censustractandblock_outliers_upper :
# Number of Observations Above Upper Bound: 4367
#
# count                 4,367.00
# mean        291,628,229,667.99
# std       6,384,671,694,092.06
# min         194,961,920,014.00
# 25%         194,990,920,998.50
# 50%         195,017,940,997.00
# 75%         195,035,020,002.00
# max     422,115,065,002,983.00
# Name: censustractandblock_outliers_upper, dtype: float64
# ------
#
# logerror_outliers_upper :
# Number of Observations Above Upper Bound: 3790
#
# count               3,790.00
# mean                    0.23
# std                     0.40
# min                     0.00
# 25%                     0.04
# 50%                     0.10
# 75%                     0.24
# max                     5.12
# Name: logerror_outliers_upper, dtype: float64
# ------

# %% [markdown]
# # Our accomplishments so far
# We have:
# - Acquired our data
# - Examinged the structure and integrity of the data
# - We have observed univariate descriptive statistics
# - We have examined null values (in total, by column, and by row)
# - We have identified upper bound outliers
# - We have created functions for these processes
#
# What we still need to do:
# - Create functions that identify lower bound outliers
# - Create functions that act on our outliers (drop them, compress them, etc.)
# - Create functions/processes that act on nulls beyond simple removal
#
# Let's look at applying some of these techniques to a new data set:

# %%
# google sheet: https://docs.google.com/spreadsheets/d/14L32EfCmr2asv85i08fla6jf1KakJVcLYaJMkXQ4_p0/edit#gid=0    
#Note: Data has been filtered/changed a bit from orginal form to demonstrate null and outlier handling.

sheet_url = 'https://docs.google.com/spreadsheets/d/14L32EfCmr2asv85i08fla6jf1KakJVcLYaJMkXQ4_p0/edit#gid=0'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df = pd.read_csv(csv_export_url)

# %%
df.head()
# Out:
#    Respondent Hobbyist                  Age Age1stCode     Comp  \
# 0           8      Yes                36.00         12   116000
# 1          14      Yes                27.00         13    66000
# 2          17      Yes                25.00         14    79000
# 3          18      Yes                32.00         12  1260000
# 4          19       No                24.00         15    83400
#
#                       Ethnicity Gender YearsCode YearsCodePro
# 0  White or of European descent    Man        17           13
# 1  White or of European descent    Man         5            1
# 2  White or of European descent    Man         7            3
# 3  White or of European descent    Man        19           12
# 4  White or of European descent    Man         9            3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8152 entries, 0 to 8151
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Respondent    8152 non-null   int64
#  1   Hobbyist      8152 non-null   object
#  2   Age           7229 non-null   float64
#  3   Age1stCode    8136 non-null   object
#  4   Comp          8152 non-null   int64
#  5   Ethnicity     3087 non-null   object
#  6   Gender        7575 non-null   object
#  7   YearsCode     8132 non-null   object
#  8   YearsCodePro  8136 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 573.3+ KB

# %%
df.hist()
plt.tight_layout()

# %%
# summarize(df)

# %% [markdown]
# Oops! Looks like our `summarize` function uses our `nulls_by_row` function and that was designed for the zillow dataset! I suppose I'll have to tweak that to make it more universal. Let's just move on for now.

# %%
df = handle_missing_values(df)
df.head()
# Out:
#    Respondent Hobbyist                  Age Age1stCode     Comp Gender  \
# 0           8      Yes                36.00         12   116000    Man
# 1          14      Yes                27.00         13    66000    Man
# 2          17      Yes                25.00         14    79000    Man
# 3          18      Yes                32.00         12  1260000    Man
# 4          19       No                24.00         15    83400    Man
#
#   YearsCode YearsCodePro
# 0        17           13
# 1         5            1
# 2         7            3
# 3        19           12
# 4         9            3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8146 entries, 0 to 8151
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Respondent    8146 non-null   int64
#  1   Hobbyist      8146 non-null   object
#  2   Age           7227 non-null   float64
#  3   Age1stCode    8134 non-null   object
#  4   Comp          8146 non-null   int64
#  5   Gender        7572 non-null   object
#  6   YearsCode     8132 non-null   object
#  7   YearsCodePro  8134 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 572.8+ KB

# %% [markdown]
# We went from 8152 entries to 8146 entries. Still a lot of nulls to be managed, but at least we have eliminated the worst offenders by column and by row.
#
# The following columns will need to be handled:
# - `Age`
# - `Age1stCode`
# - `Gender`
# - `YearsCode`
# - `YearsCodePro`

# %%
# Drop nulls for YearsCode, YearsCodePro, Age1stCode specifically

df = df.dropna(subset=['YearsCode', 'YearsCodePro', 'Age1stCode'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8108 entries, 0 to 8151
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Respondent    8108 non-null   int64
#  1   Hobbyist      8108 non-null   object
#  2   Age           7194 non-null   float64
#  3   Age1stCode    8108 non-null   object
#  4   Comp          8108 non-null   int64
#  5   Gender        7534 non-null   object
#  6   YearsCode     8108 non-null   object
#  7   YearsCodePro  8108 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 570.1+ KB

# %%
# Review values in Gender
df.Gender.value_counts()
# Out:
# Man                                                            6630
# Woman                                                           746
# Non-binary, genderqueer, or gender non-conforming                96
# Man;Non-binary, genderqueer, or gender non-conforming            30
# Woman;Non-binary, genderqueer, or gender non-conforming          27
# Woman;Man                                                         3
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       2
# Name: Gender, dtype: int64

# %%
# Impute NaNs with mode

df.Gender.mode()[0]
# Out:
# 'Man'

# %%
df['Gender'] = df.Gender.fillna(df.Gender.mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8108 entries, 0 to 8151
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Respondent    8108 non-null   int64
#  1   Hobbyist      8108 non-null   object
#  2   Age           7194 non-null   float64
#  3   Age1stCode    8108 non-null   object
#  4   Comp          8108 non-null   int64
#  5   Gender        8108 non-null   object
#  6   YearsCode     8108 non-null   object
#  7   YearsCodePro  8108 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 570.1+ KB

# %% [markdown]
# So far so good, but let's not forget what we saw in the value_counts earlier. Several of the columns have weird strings in them. Let's clean these so we can escape this object dtype.

# %%
# use replace function to reaplce strings with values

df.replace('Younger than 5 years',4, inplace = True )
df.replace('Older than 85', 85, inplace = True )
df.replace('More than 50 years', 50, inplace = True )
df.replace('Less than 1 year', 0, inplace = True )

# Now we can change datatype for these columns from 'object' to 'int64'

df['Age1stCode'] = df.Age1stCode.astype('int64')
df['YearsCode'] = df.YearsCode.astype('int64')
df['YearsCodePro'] = df.YearsCodePro.astype('int64')

# %% [markdown]
# ## Advanced Imputation Technique: KNNImputer

# %%
# split the data in train, validate and test dataframes
train, test = train_test_split(df,test_size=0.2, random_state=42)
train, validate = train_test_split(train,test_size=0.25, random_state=42)

# %%
# check the shape of three dataframes
train.shape,validate.shape, test.shape
# Out:
# ((4864, 8), (1622, 8), (1622, 8))

# %%
# use KNN imputer to find missing values for 'Age' 
from sklearn.impute import KNNImputer

#Use numeric columns that you want to use for imputation
X_numeric = train[['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']]

# define the thing
imputer = KNNImputer(n_neighbors=3)

# fit the thing (or fit and use with fit_transform) only on train!
train_imputed = imputer.fit_transform(X_numeric)
train_imputed
# Out:
# array([[41.,  5., 36., 20.],
#        [32., 11., 21.,  7.],
#        [37.,  7., 30., 18.],
#        ...,
#        [28., 16., 13.,  8.],
#        [25., 14., 11.,  2.],
#        [36., 12., 25., 14.]])

# %%
# check there is no null in imputed columns
pd.DataFrame(train_imputed).isnull().sum()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# dtype: int64

# %%
# convert imputed array to a dataframe
train_imputed = pd.DataFrame(train_imputed, index = train.index)
train_imputed.head()
# Out:
#                         0                    1                    2  \
# 1766                41.00                 5.00                36.00
# 14                  32.00                11.00                21.00
# 6270                37.00                 7.00                30.00
# 8055                32.00                24.00                 7.00
# 7801                34.33                 8.00                26.00
#
#                         3
# 1766                20.00
# 14                   7.00
# 6270                18.00
# 8055                 5.00
# 7801                12.00

# %%
# assign imputed values to the age column
train['Age'] = train_imputed[[0]]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4864 entries, 1766 to 593
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Respondent    4864 non-null   int64
#  1   Hobbyist      4864 non-null   object
#  2   Age           4864 non-null   float64
#  3   Age1stCode    4864 non-null   int64
#  4   Comp          4864 non-null   int64
#  5   Gender        4864 non-null   object
#  6   YearsCode     4864 non-null   int64
#  7   YearsCodePro  4864 non-null   int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 342.0+ KB

# %%
# do the transformation on validate and test
validate_imputed = imputer.transform(validate[['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']])
test_imputed = imputer.transform(test[['Age', 'Age1stCode', 'YearsCode', 'YearsCodePro']])

# %%
# convert arrarys from above cell in dataframes
validate_imputed = pd.DataFrame(validate_imputed, index = validate.index)
test_imputed = pd.DataFrame(test_imputed, index = test.index)

# %%
# assign imputed to 'Age' column for validate and test dataframes
validate['Age'] = validate_imputed[[0]]
test['Age'] = test_imputed[[0]]

# %% [markdown]
# ## Advanced Outlier Technique: Capping

# %%
train.head()
# Out:
#       Respondent Hobbyist                  Age  Age1stCode    Comp Gender  \
# 1766        4678      Yes                41.00           5  350000    Man
# 14            80      Yes                32.00          11   94500    Man
# 6270       49571      Yes                37.00           7  550000    Man
# 8055       62886      Yes                32.00          24  102700    Man
# 7801       60766      Yes                34.33           8  300000    Man
#
#       YearsCode  YearsCodePro
# 1766         36            20
# 14           21             7
# 6270         30            18
# 8055          7             5
# 7801         26            12

# %%
train.Age.value_counts().sort_index()
# Out:
#  1.00     1
# 17.00     4
# 18.00     7
# 19.00    12
# 20.00    19
#          ..
# 76.33     1
# 78.00     1
# 81.00     1
# 83.00     1
# 85.00     1
# Name: Age, Length: 142, dtype: int64

# %%
q1, q3 = train.Age.quantile([.25, 0.75])
iqr = q3 - q1
k = 1.5
upper_bound_age = q3 + k * iqr
upper_bound_age
# Out:
# 57.0

# %%
train[train.Age >= upper_bound_age]
# Out:
#       Respondent Hobbyist                  Age  Age1stCode    Comp Gender  \
# 6330       49736       No                57.00          31  130000    Man
# 2148        6271       No                64.00          18   95000    Man
# 2473       15395       No                63.00          14   90000    Man
# 7444       57594       No                70.00          47  136000    Man
# 1395        3711      Yes                57.00          17  105000    Man
# ...          ...      ...                  ...         ...     ...    ...
# 2661       16652      Yes                59.33          26   96000    Man
# 1298        3485       No                69.00          25  110000    Man
# 973         2719      Yes                60.00          19  240000    Man
# 5939       47759       No                70.00          40  100000    Man
# 5683       44310      Yes                63.00          15  140000    Man
#
#       YearsCode  YearsCodePro
# 6330         26            24
# 2148         36            24
# 2473         42            38
# 7444         23            22
# 1395         40            28
# ...         ...           ...
# 2661         31            31
# 1298         45            45
# 973          43            39
# 5939         25            25
# 5683         47            37
#
# [169 rows x 8 columns]

# %%
train['Age_capped'] = np.where(train.Age >= upper_bound_age, upper_bound_age, train.Age)

# %%
train.head()
# Out:
#       Respondent Hobbyist                  Age  Age1stCode    Comp Gender  \
# 1766        4678      Yes                41.00           5  350000    Man
# 14            80      Yes                32.00          11   94500    Man
# 6270       49571      Yes                37.00           7  550000    Man
# 8055       62886      Yes                32.00          24  102700    Man
# 7801       60766      Yes                34.33           8  300000    Man
#
#       YearsCode  YearsCodePro           Age_capped
# 1766         36            20                41.00
# 14           21             7                32.00
# 6270         30            18                37.00
# 8055          7             5                32.00
# 7801         26            12                34.33

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4864 entries, 1766 to 593
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Respondent    4864 non-null   int64
#  1   Hobbyist      4864 non-null   object
#  2   Age           4864 non-null   float64
#  3   Age1stCode    4864 non-null   int64
#  4   Comp          4864 non-null   int64
#  5   Gender        4864 non-null   object
#  6   YearsCode     4864 non-null   int64
#  7   YearsCodePro  4864 non-null   int64
#  8   Age_capped    4864 non-null   float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 380.0+ KB

# %%
train.Age_capped.value_counts().sort_index()
# Out:
#  1.00      1
# 17.00      4
# 18.00      7
# 19.00     12
# 20.00     19
#         ...
# 55.00     36
# 56.00     28
# 56.33      2
# 56.67      1
# 57.00    169
# Name: Age_capped, Length: 111, dtype: int64

# %%
train[['Age', 'Age_capped']].hist(figsize=(12,5), bins=20)
plt.show()

# %% [markdown]
# # Exercises
#
# Within your `codeup-data-science` directory, create a new directory named `clustering-exercises`. This will be where you do your work for this module. Create a repository on GitHub with the same name, and link your local repository to GitHub.
#
# Save your clustering work in your `clustering-exercises` repo. Then add, commit, and push your changes.
#
# For example, if the
# exercise directs you to create a file named `myfile.py`, you should have
# `clustering/myfile.py` in your repository.
#
# If a file extension is specified, you should create that specific file. If there
# is not file extension specified, you may either create a python script or a
# jupyter notebook for the exercise.
#
# !!!tip "Workflow"
#     Throughout the exercises, you may wish to do your work in a notebook, then
#     transfer any functions you've created to an external python script.
#
#     Keep in mind this is not always a linear process! You will probably be
#     cycling between a notebook and an external python script frequently.
#
#     Remember to run your code often to check for correct output and/or errors.
#
# ## Acquire (acquire.py)
#
# ### Zillow
#
# For the following, iterate through the steps you would take to create functions:
# Write the code to do the following in a jupyter notebook, test it, convert to functions, then create the file to house those functions.
#
# You will have a zillow.ipynb file and a helper file for each section in the pipeline.
#
#
# #### acquire & summarize
#
# 1. Acquire data from mySQL using the python module to connect and query. You will want to end with a single dataframe. Make sure to include: the logerror, all fields related to the properties that are available. You will end up using all the tables in the database.
#     - **_Be sure to do the correct join (inner, outer, etc.). We do not want to eliminate properties purely because they may have a null value for `airconditioningtypeid`._**
#     - Only include properties with a transaction in 2017, and include only the last transaction for each property (so no duplicate property ID's), along with zestimate error and date of transaction.
#     - Only include properties that include a latitude and longitude value.
#
# 2. Summarize your data (summary stats, info, dtypes, shape, distributions, value_counts, etc.)
# 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values.
#
# |                          | num_rows_missing | pct_rows_missing  |
# | ------------------------ |-----------------:| -----------------:|
# | parcelid                 | 0                | 0.000000          |
# | airconditioningtypeid    | 29041            | 0.535486          |
# | architecturalstyletypeid | 54232            | 0.999982          |
#
#
# 4. Write a function that takes in a dataframe and returns a dataframe with 3 columns: the number of columns missing, percent of columns missing, and number of rows with n columns missing. Run the function and document takeaways from this on how you want to handle missing values.
#
#
# | num_cols_missing  | pct_cols_missing | num_rows  |
# | ----------------- |-----------------:| ---------:|
# | 23                | 38.333           | 108       |
# | 24                | 40.000           | 123       |
# | 25                | 41.667           | 5280      |
#
# #### Prepare
#
# 1. Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer. But for this exercise, do not purely filter by unitcnt as we did previously. Add some new logic that will reduce the number of properties that are falsely removed. You might want to use # bedrooms, square feet, unit type or the like to then identify those with unitcnt not defined.
#
# 1. Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).
#     - The input:
#         - A dataframe
#         - A number between 0 and 1 that represents the proportion, for each column, of rows with non-missing values required to keep the column.  i.e. if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#         - A number between 0 and 1 that represents the proportion, for each row, of columns/variables with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
#     - The output:
#         - The dataframe with the columns and rows dropped as indicated. *Be sure to drop the columns prior to the rows in your function.*
#     - hint:
#         - Look up the dropna documentation.
#         - You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.
#         - Make use of inplace, i.e. inplace=True/False.
#
# 1. Decide how to handle the remaining missing values:
#     - Fill with constant value.
#     - Impute with mean, median, mode.
#     - Drop row/column
#
#
# #### wrangle_zillow.py
#
# Functions of the work above needed to acquire and prepare a new sample of data.

# %% [markdown]
# ### Mall Customers
#
# #### notebook
#
# 1. Acquire data from mall_customers.customers in mysql database.
# 2. Summarize data (include distributions and descriptive statistics).
# 2. Detect outliers using IQR.
# 3. Split data (train, validate, and test split).
# 3. Encode categorical columns using a one hot encoder (pd.get_dummies).
# 4. Handles missing values.
# 5. Scaling
#
# #### wrangle_mall.py
#
# 1. Acquire data from mall_customers.customers in mysql database.
# 2. Split the data into train, validate, and split
# 3. One-hot-encoding (pd.get_dummies)
# 3. Missing values
# 4. Scaling
