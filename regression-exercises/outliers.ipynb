# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

import wrangle

# %% [markdown]
# In this notebook I will attempt to determine a way to group buildings together.

# %%
strain, svalidate, stest = wrangle.wrangle_scale_zillow()

# %%
strain.corr()
# Out:
#                               bedroomcnt  bathroomcnt  \
# bedroomcnt                      1.000000     0.657147
# bathroomcnt                     0.657147     1.000000
# calculatedfinishedsquarefeet    0.671990     0.823838
# taxvaluedollarcnt               0.319077     0.517237
# yearbuilt                       0.382428     0.539145
# age                            -0.394715    -0.542439
#
#                               calculatedfinishedsquarefeet  taxvaluedollarcnt  \
# bedroomcnt                                        0.671990           0.319077
# bathroomcnt                                       0.823838           0.517237
# calculatedfinishedsquarefeet                      1.000000           0.557681
# taxvaluedollarcnt                                 0.557681           1.000000
# yearbuilt                                         0.501870           0.314608
# age                                              -0.503568          -0.308188
#
# ...

# %%
train, validate, test = wrangle.wrangle_zillow()

# %%
train.corr()
# Out:
#                               bedroomcnt  bathroomcnt  \
# bedroomcnt                      1.000000     0.640600
# bathroomcnt                     0.640600     1.000000
# calculatedfinishedsquarefeet    0.604012     0.833004
# taxvaluedollarcnt               0.253676     0.498049
# yearbuilt                       0.376396     0.509735
# age                            -0.376396    -0.509735
#
#                               calculatedfinishedsquarefeet  taxvaluedollarcnt  \
# bedroomcnt                                        0.604012           0.253676
# bathroomcnt                                       0.833004           0.498049
# calculatedfinishedsquarefeet                      1.000000           0.609422
# taxvaluedollarcnt                                 0.609422           1.000000
# yearbuilt                                         0.439157           0.189013
# age                                              -0.439157          -0.189013
#
# ...

# %%
sns.scatterplot(data=strain, x='calculatedfinishedsquarefeet', y='taxvaluedollarcnt')
# Out:
# <AxesSubplot:xlabel='calculatedfinishedsquarefeet', ylabel='taxvaluedollarcnt'>

# %%
sns.scatterplot(data=train, x='calculatedfinishedsquarefeet', y='taxvaluedollarcnt')
# Out:
# <AxesSubplot:xlabel='calculatedfinishedsquarefeet', ylabel='taxvaluedollarcnt'>
